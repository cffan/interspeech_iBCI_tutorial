# %% [markdown]
# <a href="https://colab.research.google.com/github/cffan/interspeech_iBCI_tutorial/blob/main/brain2text_tutorial_with_ans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Interspeech 24: Intracortical BCI Brain2Text Decoding Tutorial
#
# **Aims**
# 1. Explore the Brain2Text dataset.
# 2. Build a Brain2Text iBCI decoder from scratch.
# 3. Use an n-gram language model to convert phoneme probabilities into words.
#
# ![path17608.png](data:image/png;base64,...)

# %% [markdown]
# ## Install dependencies

# %%
# !pip uninstall -y torch torchvision torchaudio fastai torchtext edit_distance
# !pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu117
# !pip install edit_distance crcmod
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Collecting torch==1.13.1+cu117
#   Downloading https://download.pytorch.org/whl/cu117/torch-1.13.1%2Bcu117-cp310-cp310-linux_x86_64.whl (1801.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 1.3 MB/s eta 0:00:00
# Collecting torchvision==0.14.1+cu117
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.14.1%2Bcu117-cp310-cp310-linux_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 78.3 MB/s eta 0:00:00
# Collecting torchaudio==0.13.1
#   Downloading https://download.pytorch.org/whl/cu117/torchaudio-0.13.1%2Bcu117-cp310-cp310-linux_x86_64.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 93.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1+cu117) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu117) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu117) (2024.7.4)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.13.1+cu117 torchaudio-0.13.1+cu117 torchvision-0.14.1+cu117
# Collecting edit_distance
#   Downloading edit_distance-1.0.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting crcmod
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Downloading edit_distance-1.0.6-py3-none-any.whl (11 kB)
# Building wheels for collected packages: crcmod
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31403 sha256=7a06e5a76da4626f1be5a7392847236d5793d2083c0519735d0ed86620d4e9fa
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built crcmod
# Installing collected packages: edit_distance, crcmod
# Successfully installed crcmod-1.7 edit_distance-1.0.6

# %% [markdown]
# ## Explore the brain2text dataset

# %%
# !gsutil cp gs://cfan/interspeech24/brain2text_competition_data.pkl /content/
# Out:
# Copying gs://cfan/interspeech24/brain2text_competition_data.pkl...
# \ [1 files][  3.3 GiB/  3.3 GiB]   72.8 MiB/s
# Operation completed over 1 objects/3.3 GiB.

# %%
import pickle

with open('/content/brain2text_competition_data.pkl', 'rb') as f:
  data = pickle.load(f)

print(f'Data partitions: {list(data.keys())}')

for part, part_data in data.items():
  print(f'  {part} partition: {len(part_data)} sessions')
  for day, day_data in enumerate(part_data):
    print(f'    session {day}: {len(day_data["sentenceDat"])} trials')
  print()

print(f'Structure of each trial: {list(data["train"][0].keys())}')
# Out:
# Data partitions: ['train', 'test', 'competition']
#   train partition: 24 sessions
#     session 0: 280 trials
#     session 1: 360 trials
#     session 2: 420 trials
#     session 3: 180 trials
#     session 4: 360 trials
#     session 5: 360 trials
#     session 6: 400 trials
#     session 7: 360 trials
#     session 8: 320 trials
#     session 9: 320 trials
#     session 10: 320 trials
#     session 11: 480 trials
#     session 12: 360 trials
#     session 13: 360 trials
#     session 14: 400 trials
#     session 15: 400 trials
#     session 16: 400 trials
#     session 17: 200 trials
#     session 18: 400 trials
#     session 19: 320 trials
#     session 20: 320 trials
#     session 21: 440 trials
#     session 22: 520 trials
#     session 23: 520 trials
#
#   test partition: 24 sessions
#     session 0: 20 trials
#     session 1: 20 trials
#     session 2: 20 trials
#     session 3: 20 trials
#     session 4: 40 trials
#     session 5: 40 trials
#     session 6: 40 trials
#     session 7: 40 trials
#     session 8: 40 trials
#     session 9: 40 trials
#     session 10: 40 trials
#     session 11: 40 trials
#     session 12: 40 trials
#     session 13: 40 trials
#     session 14: 40 trials
#     session 15: 40 trials
#     session 16: 40 trials
#     session 17: 40 trials
#     session 18: 40 trials
#     session 19: 40 trials
#     session 20: 40 trials
#     session 21: 40 trials
#     session 22: 40 trials
#     session 23: 40 trials
#
#   competition partition: 15 sessions
#     session 0: 80 trials
#     session 1: 80 trials
#     session 2: 80 trials
#     session 3: 80 trials
#     session 4: 80 trials
#     session 5: 80 trials
#     session 6: 80 trials
#     session 7: 80 trials
#     session 8: 80 trials
#     session 9: 80 trials
#     session 10: 80 trials
#     session 11: 80 trials
#     session 12: 80 trials
#     session 13: 80 trials
#     session 14: 80 trials
#
# Structure of each trial: ['sentenceDat', 'transcriptions', 'phonemes', 'timeSeriesLens', 'phoneLens', 'phonePerTime']

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define 39 phonemes + silence
PHONE_DEF = [
    'AA', 'AE', 'AH', 'AO', 'AW',
    'AY', 'B',  'CH', 'D', 'DH',
    'EH', 'ER', 'EY', 'F', 'G',
    'HH', 'IH', 'IY', 'JH', 'K',
    'L', 'M', 'N', 'NG', 'OW',
    'OY', 'P', 'R', 'S', 'SH',
    'T', 'TH', 'UH', 'UW', 'V',
    'W', 'Y', 'Z', 'ZH', 'SIL'
]

# Print a trial's info
day_idx = 0
trial_idx = 10
neural_feats = data['train'][day_idx]['sentenceDat'][trial_idx]
transcription = data['train'][day_idx]['transcriptions'][trial_idx]
n_phones = data['train'][day_idx]['phoneLens'][trial_idx]
phonemes = [PHONE_DEF[p - 1] for p in data['train'][day_idx]['phonemes'][trial_idx][:n_phones]]
print(f'Shape of neural features: {neural_feats.shape}')
print(f'Sentence: {transcription}')
print(f'Phonemes: {phonemes}')

# Plot the neural features
fig, axs = plt.subplots(1, 2, figsize=(15,8))
time_axis = np.arange(0, neural_feats.shape[0], 100)
axs[0].imshow(neural_feats[:, :128].T)  # The first 128 channels correspond to threshold crossing features
axs[1].imshow(neural_feats[:, 128:].T)  # The last 128 channels correspond to spike power features
axs[0].set_xticks(time_axis)
axs[0].set_xticklabels(time_axis * 0.02)  # 20ms time bin
axs[1].set_xticklabels(time_axis * 0.02)
axs[1].set_xticks(time_axis)
axs[0].set_xlabel('Time (s)')
axs[1].set_xlabel('Time (s)')
axs[0].set_ylabel('Channels')
axs[1].set_ylabel('Channels')
axs[0].set_title('Threshold Crossing Features')
axs[1].set_title('Spike Power Features')
plt.tight_layout()
plt.show()
# Out:
# Shape of neural features: (591, 256)
# Sentence: The eastern coast is a place for pure pleasure and excitement.
# Phonemes: ['DH', 'AH', 'SIL', 'IY', 'S', 'T', 'ER', 'N', 'SIL', 'K', 'OW', 'S', 'T', 'SIL', 'IH', 'Z', 'SIL', 'AH', 'SIL', 'P', 'L', 'EY', 'S', 'SIL', 'F', 'AO', 'R', 'SIL', 'P', 'Y', 'UH', 'R', 'SIL', 'P', 'L', 'EH', 'ZH', 'ER', 'SIL', 'AH', 'N', 'D', 'SIL', 'IH', 'K', 'S', 'AY', 'T', 'M', 'AH', 'N', 'T', 'SIL']
# <ipython-input-2-b08ec88b6ae0>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(time_axis * 0.02)

# %% [markdown]
# ### Exercise 1
#
# Plot the neural features for a single channel. What do you discover?

# %%
# Your answer here

# %%
# TODO: remove this
channel_id = 50  # 0-63

plt.figure(figsize=(10,4))
plt.plot(neural_feats[:, channel_id], label='Threshold Crossing')
plt.plot(neural_feats[:, channel_id + 128], label='Spike Power')
plt.xticks(time_axis, time_axis * 0.02)
plt.ylim(-1, 5)
plt.ylabel('Feature Value')
plt.xlabel('Time (s)')
plt.title(f'Channel {channel_id} Features')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Build brain2text model

# %% [markdown]
# ### Dataset class

# %%
import torch
from torch.utils.data import Dataset


class SpeechDataset(Dataset):
    def __init__(self, data):
        self.data = data
        self.n_days = len(data)
        self.n_trials = sum([len(d["sentenceDat"]) for d in data])

        self.neural_feats = []
        self.phone_seqs = []
        self.neural_time_bins = []
        self.phone_seq_lens = []
        self.days = []
        for day in range(self.n_days):
            for trial in range(len(data[day]["sentenceDat"])):
                self.neural_feats.append(data[day]["sentenceDat"][trial])
                self.phone_seqs.append(data[day]["phonemes"][trial])
                self.neural_time_bins.append(data[day]["sentenceDat"][trial].shape[0])
                self.phone_seq_lens.append(data[day]["phoneLens"][trial])
                self.days.append(day)

    def __len__(self):
        return self.n_trials

    def __getitem__(self, idx):
        return (
            torch.tensor(self.neural_feats[idx], dtype=torch.float32),
            torch.tensor(self.phone_seqs[idx], dtype=torch.int32),
            torch.tensor(self.neural_time_bins[idx], dtype=torch.int32),
            torch.tensor(self.phone_seq_lens[idx], dtype=torch.int32),
            torch.tensor(self.days[idx], dtype=torch.int64),
        )

# %% [markdown]
# ### Model classes

# %%
import math
import numbers

from torch import nn
from torch.nn import functional as F



class GaussianSmoothing(nn.Module):
    """
    Apply gaussian smoothing on a
    1d, 2d or 3d tensor. Filtering is performed seperately for each channel
    in the input using a depthwise convolution.
    Arguments:
        channels (int, sequence): Number of channels of the input tensors. Output will
            have this number of channels as well.
        kernel_size (int, sequence): Size of the gaussian kernel.
        sigma (float, sequence): Standard deviation of the gaussian kernel.
        dim (int, optional): The number of dimensions of the data.
            Default value is 2 (spatial).
    """

    def __init__(self, channels, kernel_size, sigma, dim=2):
        super(GaussianSmoothing, self).__init__()
        if isinstance(kernel_size, numbers.Number):
            kernel_size = [kernel_size] * dim
        if isinstance(sigma, numbers.Number):
            sigma = [sigma] * dim

        # The gaussian kernel is the product of the
        # gaussian function of each dimension.
        kernel = 1
        meshgrids = torch.meshgrid(
            [torch.arange(size, dtype=torch.float32) for size in kernel_size]
        )
        for size, std, mgrid in zip(kernel_size, sigma, meshgrids):
            mean = (size - 1) / 2
            kernel *= (
                1
                / (std * math.sqrt(2 * math.pi))
                * torch.exp(-(((mgrid - mean) / std) ** 2) / 2)
            )

        # Make sure sum of values in gaussian kernel equals 1.
        kernel = kernel / torch.sum(kernel)

        # Reshape to depthwise convolutional weight
        kernel = kernel.view(1, 1, *kernel.size())
        kernel = kernel.repeat(channels, *[1] * (kernel.dim() - 1))

        self.register_buffer("weight", kernel)
        self.groups = channels

        if dim == 1:
            self.conv = F.conv1d
        elif dim == 2:
            self.conv = F.conv2d
        elif dim == 3:
            self.conv = F.conv3d
        else:
            raise RuntimeError(
                "Only 1, 2 and 3 dimensions are supported. Received {}.".format(dim)
            )

    def forward(self, input):
        """
        Apply gaussian filter to input.
        Arguments:
            input (torch.Tensor): Input to apply gaussian filter on.
        Returns:
            filtered (torch.Tensor): Filtered output.
        """
        return self.conv(input, weight=self.weight, groups=self.groups, padding="same")


class GRUDecoder(nn.Module):
    """
    GRU Decoder

    Arguments:
      neural_dim (int): Number of channels in the input neural features.
      n_classes (int): Number of classes in the output sequence.
      hidden_dim (int): Number of hidden units in the GRU layer.
      layer_dim (int): Number of layers in the GRU layer.
      n_days (int): Number of day-specific transform layer.
      dropout (float): GRU dropout rate.
      stride (int): Stride of sliding window for feature stacking.
      kernel (int): Kernel size of sliding window for feature stacking.
      gaussian_smooth_sigma (float): Standard deviation of gaussian smoothing.
      gaussian_smooth_kernel (int): Kernel size of gaussian smoothing.
      bidirectional (bool): Whether to use bidirectional GRU layer.
    """
    def __init__(
        self,
        neural_dim,
        n_classes,
        hidden_dim,
        n_layers,
        n_days,
        dropout=0,
        stride=4,
        kernel=14,
        gaussian_smooth_sigma=2,
        gaussian_smooth_kernel=20,
        bidirectional=False,
    ):
        super(GRUDecoder, self).__init__()

        self.n_layers = n_layers
        self.hidden_dim = hidden_dim
        self.neural_dim = neural_dim
        self.n_classes = n_classes
        self.n_days = n_days
        self.dropout = dropout
        self.stride = stride
        self.kernel = kernel
        self.bidirectional = bidirectional
        self.gru_output_dim = hidden_dim * 2 if bidirectional else hidden_dim
        self.input_layer_nonlinearity = torch.nn.Softsign()
        self.unfolder = torch.nn.Unfold((self.kernel, 1), dilation=1, padding=0, stride=self.stride)
        self.gaussian_smooth = GaussianSmoothing(neural_dim, gaussian_smooth_kernel, gaussian_smooth_sigma, dim=1)

        # Parameters for day-specific layers
        self.day_weights = torch.nn.Parameter(torch.randn(n_days, neural_dim, neural_dim))
        self.day_bias = torch.nn.Parameter(torch.zeros(n_days, 1, neural_dim))

        for x in range(n_days):
            self.day_weights.data[x, :, :] = torch.eye(neural_dim)  # Initialize day-specific transforms with identity matrix

        # GRU layers
        self.gru_decoder = nn.GRU(
            neural_dim * self.kernel,  # Stacked inputs
            hidden_dim,
            n_layers,
            batch_first=True,
            dropout=self.dropout,
            bidirectional=self.bidirectional,
        )

        # Linear output layer
        self.fc_decoder_out = nn.Linear(self.gru_output_dim, n_classes + 1)  # +1 for CTC blank

    def forward(self, neural_feats, neural_feats_lens, day_idx):
        """
        Arguments:
          neural_feats (torch.Tensor): Input neural features. Shape: (batch, time, channels).
          day_idx (torch.Tensor): Day index.
        """

        # Gaussian smoothing
        neural_feats = torch.permute(neural_feats, (0, 2, 1))
        neural_feats = self.gaussian_smooth(neural_feats)
        neural_feats = torch.permute(neural_feats, (0, 2, 1))

        # Apply day-specific transform
        day_weights = torch.index_select(self.day_weights, 0, day_idx)
        neural_feats = torch.einsum("btd,bdk->btk", neural_feats, day_weights) + \
            torch.index_select(self.day_bias, 0, day_idx)
        neural_feats = self.input_layer_nonlinearity(neural_feats)

        # Stacking features with a sliding window
        stacked_neural_feats = torch.permute(
            self.unfolder(torch.unsqueeze(torch.permute(neural_feats, (0, 2, 1)), 3)),
            (0, 2, 1),
        )

        # GRU
        batch_size = stacked_neural_feats.size(0)
        h0 = torch.zeros(
            self.n_layers * 2 if self.bidirectional else self.n_layers,
            batch_size,
            self.hidden_dim,
            device=neural_feats.device,
        )
        h, _ = self.gru_decoder(stacked_neural_feats, h0)

        # Linear output layer
        output = self.fc_decoder_out(h)
        output_lens = ((neural_feats_lens - self.kernel) / self.stride + 1).to(torch.int32)
        return output, output_lens

# %% [markdown]
# ### Training loop

# %%
import os
import pickle
import time

from edit_distance import SequenceMatcher
import numpy as np
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader


def get_dataset_loaders(
    data_path,
    batch_size,
    day_indices=None,
):
    with open(data_path, "rb") as handle:
        loaded_data = pickle.load(handle)

    # Pad neural features and phoneme labels
    def _padding(batch):
        X, y, X_lens, y_lens, days = zip(*batch)
        X_padded = pad_sequence(X, batch_first=True, padding_value=0)
        y_padded = pad_sequence(y, batch_first=True, padding_value=0)

        return (
            X_padded,
            y_padded,
            torch.stack(X_lens),
            torch.stack(y_lens),
            torch.stack(days),
        )

    # Load data according to the day indices
    if day_indices is None:
        day_indices = list(range(len(loaded_data["train"])))
    train_ds = SpeechDataset([loaded_data["train"][d] for d in day_indices])
    test_ds = SpeechDataset([loaded_data["test"][d] for d in day_indices])

    # Set up dataloaders
    train_loader = DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0,
        pin_memory=True,
        collate_fn=_padding,
    )
    test_loader = DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=True,
        collate_fn=_padding,
    )

    return train_loader, test_loader, loaded_data

def eval_model(model, test_loader, device, loss_func=None, test_day_idx=None):

  with torch.no_grad():
    model.eval()

    test_losses = []
    decoded_seqs = []
    true_seqs = []
    total_edit_distance = 0
    total_seq_length = 0
    for X, y, X_lens, y_lens, day_idx in test_loader:
        X, y, X_lens, y_lens, day_idx = (
            X.to(device),
            y.to(device),
            X_lens.to(device),
            y_lens.to(device),
            day_idx.to(device),
        )
        if test_day_idx is not None:
          day_idx = torch.tensor([test_day_idx] * X.shape[0]).to(device)

        pred, pred_lens = model.forward(X, X_lens, day_idx)
        if loss_func is not None:
          loss = loss_func(
              torch.permute(pred.log_softmax(2), [1, 0, 2]),
              y,
              pred_lens,
              y_lens,
          )
          loss = torch.sum(loss)
          test_losses.append(loss.cpu().detach().numpy())

        # Compute CER
        for j in range(pred.shape[0]):
            decoded_seq = torch.argmax(pred[j, 0:pred_lens[j], :], dim=-1)
            decoded_seq = torch.unique_consecutive(decoded_seq, dim=-1)
            decoded_seq = decoded_seq.cpu().detach().numpy()
            decoded_seq = np.array([i for i in decoded_seq if i != 0])

            true_seq = np.array(y[j][0:y_lens[j]].cpu().detach())

            matcher = SequenceMatcher(
                a=true_seq.tolist(), b=decoded_seq.tolist()
            )
            total_edit_distance += matcher.distance()
            total_seq_length += len(true_seq)
            decoded_seqs.append(decoded_seq)
            true_seqs.append(true_seq)

    cer = total_edit_distance / total_seq_length
    mean_loss = np.mean(test_losses) if len(test_losses) > 0 else 0
    return cer, decoded_seqs, true_seqs, mean_loss


def train_model(args):
    torch.manual_seed(args["seed"])
    np.random.seed(args["seed"])
    device = args["device"]

    if not os.path.exists(args["output_dir"]):
      os.makedirs(args["output_dir"])

    # Load data
    train_loader, test_loader, loaded_data = get_dataset_loaders(
        args["dataset_path"],
        args["batch_size"],
        args["day_indices"]
    )

    # Build model
    model = GRUDecoder(
        neural_dim=args["neural_feats_dim"],
        n_classes=args["phone_classes"],
        hidden_dim=args["gru_hidden_units"],
        n_layers=args["gru_layers"],
        n_days=len(args["day_indices"]),
        dropout=args["dropout"],
        stride=args["stride"],
        kernel=args["kernel"],
        gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
        gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
        bidirectional=args["bidirectional"],
    ).to(device)

    # Build loss and optimizer
    loss_ctc = torch.nn.CTCLoss(blank=0, reduction="mean", zero_infinity=True)
    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=args["lr_start"],
        betas=(0.9, 0.999),
        eps=0.1,
        weight_decay=args["l2_decay"],
    )
    scheduler = torch.optim.lr_scheduler.LinearLR(
        optimizer,
        start_factor=1.0,
        end_factor=args["lr_end"] / args["lr_start"],
        total_iters=args["train_batches"],
    )

    # Train
    train_loss = []
    test_loss = []
    test_cer = []
    for batch in range(args["train_batches"]):
        model.train()

        X, y, X_lens, y_lens, day_idx = next(iter(train_loader))
        X, y, X_lens, y_lens, day_idx = (
            X.to(device),
            y.to(device),
            X_lens.to(device),
            y_lens.to(device),
            day_idx.to(device),
        )

        # Noise augmentation is faster on GPU
        if args["white_noise_sd"] > 0:
            X += torch.randn(X.shape, device=device) * args["white_noise_sd"]
        if args["constant_offset_noise_sd"] > 0:
            X += (
                torch.randn([X.shape[0], 1, X.shape[2]], device=device)
                * args["constant_offset_noise_sd"]
            )

        # Forward pass
        pred, pred_lens = model.forward(X, X_lens, day_idx)
        loss = loss_ctc(
            torch.permute(pred.log_softmax(2), [1, 0, 2]),
            y,
            pred_lens,
            y_lens,
        )
        loss = torch.sum(loss)
        train_loss.append(loss.cpu().detach().numpy())

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        # Eval
        if batch % 100 == 99:
            cer, _, _, test_loss = eval_model(model, test_loader, device, loss_func=loss_ctc)
            test_cer.append(cer)
            print(
                f"batch {batch}, train loss: {np.mean(train_loss):>4f}, test loss: {test_loss:>4f}, test cer: {cer:>4f}"
            )
            train_loss = []

            if len(test_cer) > 0 and cer <= np.min(test_cer):
                torch.save(model.state_dict(), f"{args['output_dir']}/model.pt")

# %% [markdown]
# ### Train a toy model

# %%
args = {}
args['dataset_path'] = '/content/brain2text_competition_data.pkl'
args['output_dir'] = '/content/brain2text_toy_model/'
args['day_indices'] = [0, 1, 2, 3]
args['batch_size'] = 64
args['lr_start'] = 0.02
args['lr_end'] = 0.02
args['gru_hidden_units'] = 128
args['train_batches'] = 5000
args['gru_layers'] = 2
args['seed'] = 0
args['phone_classes'] = 40
args['neural_feats_dim'] = 256
args['dropout'] = 0.4
args['white_noise_sd'] = 0.8
args['constant_offset_noise_sd'] = 0.2
args['gaussian_smooth_sigma'] = 2.0
args['gaussian_smooth_kernel'] = 20
args['stride'] = 4
args['kernel'] = 5
args['bidirectional'] = False
args['l2_decay'] = 1e-5
args['device'] = 'cuda'

train_model(args)

# %% [markdown]
# #### Exercise 2
#
# Download models trained on 1 day, 4 days, 8 days, and 24 days of data. Plot the phoneme error rate (PER) of each model. How does the PER change as the number of training days increase?

# %%
# Download all models
# !gsutil cp -r gs://cfan/interspeech24/brain2text_model_1-day /content/
# !gsutil cp -r gs://cfan/interspeech24/brain2text_model_4-day /content/
# !gsutil cp -r gs://cfan/interspeech24/brain2text_model_8-day /content/
# !gsutil cp -r gs://cfan/interspeech24/brain2text_model_24-day /content/
# Out:
# Copying gs://cfan/interspeech24/brain2text_model_1-day/model.pt...
# / [1 files][  2.7 MiB/  2.7 MiB]
# Operation completed over 1 objects/2.7 MiB.
# Copying gs://cfan/interspeech24/brain2text_model_4-day/model.pt...
# / [1 files][  3.5 MiB/  3.5 MiB]
# Operation completed over 1 objects/3.5 MiB.
# Copying gs://cfan/interspeech24/brain2text_model_8-day/model.pt...
# / [1 files][  4.5 MiB/  4.5 MiB]
# Operation completed over 1 objects/4.5 MiB.
# Copying gs://cfan/interspeech24/brain2text_model_24-day/model.pt...
# / [1 files][  8.5 MiB/  8.5 MiB]
# Operation completed over 1 objects/8.5 MiB.

# %%
# Load the 1-day model and evaluate its PER
model_path = "/content/brain2text_model_1-day/model.pt"

# Data loaders for 1-day model
day_indices = list(range(1))
_, test_loader, _ = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    day_indices
)

model_1day = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=len(day_indices),
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model_1day.load_state_dict(torch.load(model_path, map_location=args["device"]))

per_1day, decoded_seqs, true_seqs, _ = eval_model(model_1day, test_loader, args["device"], loss_func=None)
print(f'1-day model PER: {per_1day:.2f}')

print()
print('Examples of decoded phoneme sequences')
for decoded_seq, true_seq in zip(decoded_seqs, true_seqs):
  print('HYP: ' + ' '.join([PHONE_DEF[p - 1] for p in decoded_seq]))
  print('REF: ' + ' '.join([PHONE_DEF[p - 1] for p in true_seq]))
  print()
  break
# Out:
# 1-day model PER: 0.47
#
# Examples of decoded phoneme sequences
# HYP: DH IH S SIL K IH S SIL R IH K AE N AH D SIL
# REF: TH IY AA K R AH S IY SIL R IY K AH N S IH D ER D SIL

# %%
# Your answer here

# Load the 4-day, 8-day, 24-day models and plot their PER against number of training days

# %%
# TODO: remove this
# Load the 4-day model and evaluate its PER
model_path = "/content/brain2text_model_4-day/model.pt"

# Data loaders for 4-day model
day_indices = list(range(4))
_, test_loader, _ = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    day_indices
)

model_4day = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=len(day_indices),
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model_4day.load_state_dict(torch.load(model_path, map_location=args["device"]))

per_4day, _, _, _ = eval_model(model_4day, test_loader, args["device"], loss_func=None)
print(f'4-day model PER: {per_4day:.2f}')
# Out:
# 4-day model PER: 0.43

# %%
# TODO: remove this
# Load the 8-day model and evaluate its PER
model_path = "/content/brain2text_model_8-day/model.pt"

# Data loaders for 4-day model
day_indices = list(range(8))
_, test_loader, _ = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    day_indices
)

model_8day = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=len(day_indices),
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model_8day.load_state_dict(torch.load(model_path, map_location=args["device"]))

per_8day, decoded_seqs, true_seqs, _ = eval_model(model_8day, test_loader, args["device"], loss_func=None)
print(f'8-day model PER: {per_8day:.2f}')
# Out:
# 8-day model PER: 0.37

# %%
# TODO: remove this
# Load the 24-day model and evaluate its PER
model_path = "/content/brain2text_model_24-day/model.pt"

# Data loaders for 24-day model
day_indices = list(range(24))
_, test_loader, _ = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    day_indices
)

model_24day = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=len(day_indices),
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model_24day.load_state_dict(torch.load(model_path, map_location=args["device"]))

per_24day, decoded_seqs, true_seqs, _ = eval_model(model_24day, test_loader, args["device"], loss_func=None)
print(f'24-day model PER: {per_24day:.2f}')
# Out:
# 24-day model PER: 0.32

# %%
# TODO: remove this
plt.figure()
plt.plot([1, 4, 8, 24], [per_1day, per_4day, per_8day, per_24day], 'o-')
plt.xlabel('Number of training days')
plt.ylabel('PER')
plt.title('PER vs. Number of Training Days')
plt.show()

# %% [markdown]
# #### Exercise 3
#
# Let's take a look at neural non-stationarity. Intracortical neural recordings change all the time. Let's take the 4-day model (trained on day 0, 1, 2, 3) and plot its PER on future days (day 4 - 23). What does the trend tell you about the non-staionarity?

# %%
# Load the 4-day model
model_path = "/content/brain2text_model_4-day/model.pt"
model_4day = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=4,
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model_4day.load_state_dict(torch.load(model_path, map_location=args["device"]))
# Out:
# <All keys matched successfully>

# %%
# Data loader for day 3
_, test_loader, _ = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    day_indices=[3]
)

# Evaluate the model on day 3's data and day 3's transform
per, _, _, _ = eval_model(model_4day, test_loader, args["device"], test_day_idx=3)
print(per)
# Out:
# 0.4080717488789238

# %%
# Evaluate PER on day 4 - 23. Plot the PER for each day.

# %%
# TODO: remove this

pers = []
for day_idx in range(4, 24):
  _, test_loader, _ = get_dataset_loaders(
      args["dataset_path"],
      args["batch_size"],
      day_indices=[day_idx]
  )

  # Evaluate the model on day 4's data and day 3's transform
  per, _, _, _ = eval_model(model_4day, test_loader, args["device"], test_day_idx=3)
  pers.append(per)
  print(f'Day {day_idx}: {per}')

plt.figure()
plt.plot(range(4, 24), pers, 'o-')
plt.xlabel('Day')
plt.ylabel('PER')
plt.title('PER vs. Day')
plt.show()
# Out:
# Day 4: 0.4080717488789238
# Day 5: 0.4670433145009416
# Day 6: 0.5704824976348155
# Day 7: 0.5739750445632799
# Day 8: 0.6549800796812749
# Day 9: 0.7083333333333334
# Day 10: 0.6972878390201225
# Day 11: 0.6902573529411765
# Day 12: 0.6979553903345725
# Day 13: 0.7180067950169875
# Day 14: 0.7243532560214094
# Day 15: 0.7274368231046932
# Day 16: 0.7291005291005291
# Day 17: 0.7166831194471865
# Day 18: 0.7095343680709535
# Day 19: 0.7147087857847977
# Day 20: 0.7256281407035176
# Day 21: 0.7207122774133083
# Day 22: 0.7293790546802595
# Day 23: 0.7520833333333333

# %% [markdown]
# ## Phonemes to words decoding with n-gram language model

# %% [markdown]
# ### Install the n-gram LM decoder

# %%
# Install LM Decoder (based on Kaldi and WeNet)
# %cd /content
# !git clone https://github.com/fwillett/speechBCI.git
# %cd speechBCI
# !git checkout interspeech
# !cd LanguageModelDecoder/runtime/server/x86/ && CMAKE_BUILD_PARALLEL_LEVEL=4 pip install .
# Out:
# /content
# Cloning into 'speechBCI'...
# remote: Enumerating objects: 3036, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 3036 (delta 75), reused 156 (delta 70), pack-reused 2868 (from 1)
# Receiving objects: 100% (3036/3036), 78.36 MiB | 48.84 MiB/s, done.
# Resolving deltas: 100% (410/410), done.
# /content/speechBCI
# Branch 'interspeech' set up to track remote branch 'interspeech' from 'origin'.
# Switched to a new branch 'interspeech'
# Processing /content/speechBCI/LanguageModelDecoder/runtime/server/x86
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: lm_decoder
#   Building wheel for lm_decoder (setup.py) ... done
#   Created wheel for lm_decoder: filename=lm_decoder-0.0.1-cp310-cp310-linux_x86_64.whl size=660177 sha256=055a518737b09f6be4932ff7e7a4ca442ed300ba0c8c093dd65b1ef25ce1a8e5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pmm9zvti/wheels/8f/c5/7f/3629b0f29c8d6841e4805863da61401a872f30d99d575f865d
# Successfully built lm_decoder
# Installing collected packages: lm_decoder
# Successfully installed lm_decoder-0.0.1

# %%
# Download the 3-gram LM (trained on OpenWebText2)
# %cd /content/
# !gsutil -m cp gs://cfan/interspeech24/3gram.tar.gz ./
# !tar -zxvf 3gram.tar.gz
# Out:
# /content
# Copying gs://cfan/interspeech24/3gram.tar.gz...
# Resuming download for ./3gram.tar.gz component 0
# Resuming download for ./3gram.tar.gz component 2
# Resuming download for ./3gram.tar.gz component 3
# Resuming download for ./3gram.tar.gz component 1
# / [1/1 files][  4.2 GiB/  4.2 GiB] 100% Done  69.1 MiB/s ETA 00:00:00
# Operation completed over 1 objects/4.2 GiB.
# speech_3gram/
# speech_3gram/TLG.fst
# speech_3gram/words.txt

# %% [markdown]
# ### Load a pretrained GRU decoder

# %%
# Download pretrained GRU decoder
# %cd /content
# !gsutil cp -r gs://cfan/interspeech24/brain2text_model_full/ /content
# Out:
# /content
# Copying gs://cfan/interspeech24/brain2text_model_full/model.pt...
# / [1 files][402.6 MiB/402.6 MiB]
# Operation completed over 1 objects/402.6 MiB.

# %%
# Load the model
args = {}
args['dataset_path'] = '/content/brain2text_competition_data.pkl'
args['output_dir'] = '/content/brain2text_model_full/'
args['day_indices'] = list(range(24))
args['batch_size'] = 64
args['lr_start'] = 0.02
args['lr_end'] = 0.02
args['gru_hidden_units'] = 1024
args['train_batches'] = 10000
args['gru_layers'] = 5
args['seed'] = 0
args['phone_classes'] = 40
args['neural_feats_dim'] = 256
args['dropout'] = 0.4
args['white_noise_sd'] = 0.8
args['constant_offset_noise_sd'] = 0.2
args['gaussian_smooth_sigma'] = 2.0
args['gaussian_smooth_kernel'] = 20
args['stride'] = 4
args['kernel'] = 14
args['bidirectional'] = True
args['l2_decay'] = 1e-5
args['device'] = 'cuda'


train_loader, test_loader, loaded_data = get_dataset_loaders(
    args["dataset_path"],
    args["batch_size"],
    args["day_indices"]
)

model = GRUDecoder(
    neural_dim=args["neural_feats_dim"],
    n_classes=args["phone_classes"],
    hidden_dim=args["gru_hidden_units"],
    n_layers=args["gru_layers"],
    n_days=len(loaded_data["train"]),
    dropout=args["dropout"],
    stride=args["stride"],
    kernel=args["kernel"],
    gaussian_smooth_sigma=args["gaussian_smooth_sigma"],
    gaussian_smooth_kernel=args["gaussian_smooth_kernel"],
    bidirectional=args["bidirectional"],
).to(args["device"])

model.load_state_dict(torch.load(f"{args['output_dir']}/model.pt", map_location=args["device"]))
# Out:
# <All keys matched successfully>

# %%
# Evaluate the model
per, decoded_seqs, true_seqs, _ = eval_model(model, test_loader, args["device"], loss_func=None)
print(f'PER: {per:.2f}')
# Out:
# PER: 0.20

# %% [markdown]
# ### Phonemes to words decoding

# %%
# Load LM
import lm_decoder

lm_dir = "/content/speech_3gram"

# Beam search parameters (See Kaldi's documentation)
decode_opts = lm_decoder.DecodeOptions(
    7000,  # max active,
    200,   # min active,
    17,    # beam,
    8,     # lattice_beam,
    0.5,   # acoustic_scale,
    1.0,   # ctc_blank_skip_threshold,
    0.0,   # length_penalty,
    100,   # nbest
)

decode_resource = lm_decoder.DecodeResource(
    f"{lm_dir}/TLG.fst",
    "",  # G.fst path
    "",   # rescore_G.fst path
    f"{lm_dir}/words.txt",
    ""
)
ngram_decoder = lm_decoder.BrainSpeechDecoder(decode_resource, decode_opts)

# %%
# Get the logits (phoneme probabilities) from the GRU decoder

import re

rnn_outputs = {
    "logits": [],
    "logitLengths": [],
    "trueSeqs": [],
    "transcriptions": [],
}

device = args["device"]
with torch.no_grad():
  model.eval()

  for test_day_idx in range(len(loaded_data["test"])):
    # Construct a test loader
    test_ds = SpeechDataset([loaded_data["test"][test_day_idx]])
    test_loader = torch.utils.data.DataLoader(
        test_ds, batch_size=1, shuffle=False, num_workers=0
    )

    # Evaluate the model
    for j, (X, y, X_lens, y_lens, _) in enumerate(test_loader):
      X, y, X_lens, y_lens, days = (
          X.to(device),
          y.to(device),
          X_lens.to(device),
          y_lens.to(device),
          torch.tensor([test_day_idx], dtype=torch.int64).to(device),
      )

      # Get the logits and logit lengths for the LM decoder
      logits, logit_lens = model.forward(X, X_lens, days)
      rnn_outputs["logits"].append(logits[0].cpu().detach().numpy())
      rnn_outputs["logitLengths"].append(logit_lens[0].cpu().detach().item())

      # Get the ground truth phoneme sequence to compute PER
      true_seq = np.array(y[0][0:y_lens[0]].cpu().detach())
      rnn_outputs["trueSeqs"].append(true_seq)

      # Get the transcription to compute WER
      transcript = loaded_data["test"][test_day_idx]["transcriptions"][j].strip()
      transcript = re.sub(r"[^a-zA-Z\- \']", "", transcript)  # Remove non-alphabetic characters
      transcript = transcript.replace("--", "").lower()
      rnn_outputs["transcriptions"].append(transcript)

# %%
# Decode phoneme probabilities to words

decoded_sentences = []
transcriptions = rnn_outputs['transcriptions']
blank_penalty = np.log(7)  # CTC blank penalty

for l in range(len(rnn_outputs['logits'])):
    logits = rnn_outputs['logits'][l]
    # Reshape logits to kaldi order: CTC_BLANK, SIL, PHONEMES
    logits = np.concatenate([logits[:, 0:1], logits[:, -1:], logits[:, 1:-1]], axis=-1)
    logit_len = rnn_outputs['logitLengths'][l]
    log_prior = np.zeros([1, logits.shape[1]])  # No prior on phonemes

    ngram_decoder.Reset()
    lm_decoder.DecodeNumpy(ngram_decoder, logits[:logit_len], log_prior, blank_penalty)
    ngram_decoder.FinishDecoding()

    if len(ngram_decoder.result()) == 0:
      decoded = ''
    else:
      decoded = ngram_decoder.result()[0].sentence

    decoded_sentences.append(decoded.strip())

# %%
# Compute WER

from edit_distance import SequenceMatcher

total_words = 0
total_distance = 0
for decoded, transcript in zip(decoded_sentences, rnn_outputs['transcriptions']):
  print(f'REF: {transcript}')
  print(f'HYP: {decoded}')
  print()

  decoded = decoded.split(" ")
  transcript = transcript.split(" ")

  total_words += len(transcript)
  matcher = SequenceMatcher(decoded, transcript)
  total_distance += matcher.distance()

print(f'WER: {total_distance / total_words:.2f}')
# Out:
# REF: theocracy reconsidered
# HYP: this weekend
#
# REF: rich purchased several signed lithographs
# HYP: last post ever signed lithograph
#
# REF: so rules we made in unabashed collusion
# HYP: the rules we met in and of collusion
#
# REF: lori's costume needed black gloves to be completely elegant
# HYP: cruz came did make love to be completely alien
#
# REF: the tooth fairy forgot to come when roger's tooth fell out
# HYP: the tooth fairy weak to come when workers to fill out
#
# REF: that stinging vapor was caused by chloride vaporization
# HYP: that thing if i was called the wide separation
#
# REF: before thursday's exam review every formula
# HYP: before thursday's game was ever formally
#
# REF: wildfire near sunshine forces park closures
# HYP: while new zealand first party
#
# REF: the word means it won't boil away easily nothing else
# HYP: the word means it won't boil away usually nothing else
#
# REF: would a blue feather in a man's hat make him happy all day
# HYP: would a bull phase in a man's height make him about all day
#
# REF: he talked about unauthentic storylines too
# HYP: talk about an authentic story line u
#
# REF: most young rise early every morning
# HYP: most young rise early every morning
#
# REF: with this no loyal citizen can quarrel
# HYP: with this new local children can kill
#
# REF: primitive tribes have an upbeat attitude
# HYP: many times have an upbeat attitude
#
# REF: and it was not a judge but a justice of the peace who made the decision
# HYP: and was not a new beta test of the past who made the decision
#
# REF: we seemed to be witnessing the population explosion right in our own backyards
# HYP: we seem to be earning the population explosion right in your own backers
#
# REF: sometimes desperate measures can also turn into solid moves for the future
# HYP: as desperate measures can also tune in at more for the future
#
# REF: those answers will be straightforward if you think them through carefully first
# HYP: the ancient will be straight forward is if you think them through carefully first u
#
# REF: she gets dressed faster and spends less energy making clothing decisions
# HYP: we get together and spend less energy making charging decisions
#
# REF: academic aptitude guarantees your diploma
# HYP: cannabis act is your dilemma
#
# REF: to some extent predispositions are shaped by exposure to group environments
# HYP: to select pieces are shaped by exposure to drop in violence
#
# REF: an adult male baboon's teeth are not suitable for eating shellfish
# HYP: an adult male baboons things are not suitable for eating shellfish
#
# REF: in this context it would do well for us to bear in mind the vision of peace
# HYP: in the long it would do well for us to bear in mind the vision of peace
#
# REF: you're boiling milk ain't you
# HYP: you're boiling milk and u
#
# REF: rich looked for spotted hyenas and jaguars on the safari
# HYP: we look for solid hands and legs on the supporters
#
# REF: traffic frequently has failed to measure up to engineers' rosy estimates
# HYP: traffic authority has failed to make up to any other elements
#
# REF: ralph prepared red snapper with fresh lemon sauce for dinner
# HYP: ralph beard red tape was fresh lemon slices for dinner
#
# REF: did you buy any corduroy overalls
# HYP: did you buy any controls
#
# REF: clear pronunciation is appreciated
# HYP: your donation is appreciated
#
# REF: please shorten this skirt for joyce
# HYP: place in this kit for choice
#
# REF: who authorized the unlimited expense account
# HYP: who authored the ultimate expense account
#
# REF: the family requests that flowers be omitted
# HYP: the family and that could be imminent
#
# REF: the museum hires musicians every evening
# HYP: the museum our position ever since
#
# REF: we'll serve rhubarb pie after rachel's talk
# HYP: while to youtube by after sexual talk
#
# REF: they enjoy it when i audition
# HYP: they consider it when i audition
#
# REF: the avocado should have a give to it as you hold it when it is ripe
# HYP: the article should have to get to it as you it's one that is ripe
#
# REF: energy suppliers usually deal with this by conducting regular inspections and trimming
# HYP: any players usually deal with it by conducting regular inspections and team
#
# REF: the saw is broken so chop the wood instead
# HYP: the store is working to stop the food inside
#
# REF: the cleaned version is given below
# HYP: the clean version is given below
#
# REF: they seem darned proud of it
# HYP: they seem and sound of it
#
# REF: a sharp tremor was followed by a jerky roll
# HYP: a job tremor was followed by a lucky roll
#
# REF: boy you ain't fooling nobody but yourself
# HYP: but you ain't fooling nobody but yourself
#
# REF: teaching guides are included with each record
# HYP: six guys are included with each week
#
# REF: the man's eyelids fluttered
# HYP: the man's eyelids fluttered
#
# REF: this kid's froze bad
# HYP: this kid was bad
#
# REF: she radiated warmth and good fellowship
# HYP: she radiates warmth and good fellowship
#
# REF: do you know where it might have gone
# HYP: do you know where it might have gone
#
# REF: in the pity for them his loneliness was gone
# HYP: in the place for them his countless was gone
#
# REF: join us on twitter and facebook
# HYP: join us on twitter and facebook
#
# REF: he said they'll be working toward a decision
# HYP: he said they'll be working toward a decision
#
# REF: shaving cream is a popular item on halloween
# HYP: every game is a popular item on halloween
#
# REF: then simmer fifteen minutes longer
# HYP: then simmer even much longer
#
# REF: a third shot doused the light
# HYP: a third shot at the light
#
# REF: the guttural language from the ghetto stopped
# HYP: the guttural language from the little steps
#
# REF: like as if it were built of books
# HYP: not as if it were built of books
#
# REF: then he  then what
# HYP: then he then what
#
# REF: i am an artist lost in my own vision
# HYP: i am an artist just in my own vision
#
# REF: blockade is one answer offered by experts
# HYP: blockade is one answer offered by experts
#
# REF: those musicians harmonize marvelously
# HYP: those musicians and movie
#
# REF: it all did look very efficient and shipshape
# HYP: it also did look very efficient and cheap
#
# REF: yet we no longer feel uneasy
# HYP: that was no longer feel uneasy
#
# REF: inflammatory cells were strikingly absent
# HYP: inflammatory cells were really happened
#
# REF: it can project long-range goals for itself
# HYP: it can get along really well for itself
#
# REF: intelligence jabbed at him accusingly
# HYP: in a mad at him personally
#
# REF: do you hear the sleigh bells ringing
# HYP: do you hear the baby bells ringing
#
# REF: there was much embracing much exclaiming
# HYP: there was much amazing much acclaim
#
# REF: below is a specific guide keyed to the calendar
# HYP: well as a specific goal is to the lander
#
# REF: finally he asked do you object to petting
# HYP: finally he asked do you expect to pay
#
# REF: we'll pay you back if you'll let us
# HYP: i'll pay you back of all let us
#
# REF: they close sometime after eight
# HYP: they closed sometime after it
#
# REF: then we were off again
# HYP: then we were off again
#
# REF: his wife didn't give a sign she'd heard
# HYP: his wife did have a sound she heard
#
# REF: for a man of his mass he was curiously short
# HYP: for a man of his mess he was really short
#
# REF: pam gives driving lessons on thursdays
# HYP: sam is giving lessons on thursday's
#
# REF: read the decision below
# HYP: with the decision by
#
# REF: receiving no answer they set the fire
# HYP: received no answer they set the fire
#
# REF: where is your usual upbeat personality
# HYP: why is to usually a bit personally
#
# REF: nice country to meet a lion in face to face
# HYP: the country to meet a line and face to face
#
# REF: with a whirling jump it could get into gear
# HYP: with a wall up it could get into play
#
# REF: marksmanship example
# HYP: but one example
#
# REF: it's really hard to find something that works
# HYP: it's really hard to find something that works
#
# REF: and i loved ths shining
# HYP: and i love the signing
#
# REF: i do have a friend that ran
# HYP: i do have a friend that one
#
# REF: just way in the back
# HYP: just why in the back
#
# REF: actually it makes sense to a certain extent
# HYP: actually it makes sense to a certain extent
#
# REF: assure the government that he was employed
# HYP: to the government that he was employed
#
# REF: they feel good about what they're doing
# HYP: they feel good about what they're doing
#
# REF: besides its an invasion of personal privacy
# HYP: besides it's an invasion of personal privacy
#
# REF: so you travel a lot
# HYP: so you travel a lot
#
# REF: so we're going to wait
# HYP: so we're going to write
#
# REF: any kind of a good environment to live in
# HYP: any kind of a good environment to live in
#
# REF: the best of android
# HYP: the best of android
#
# REF: i don't know what you think about the point
# HYP: i don't know what you think about the point
#
# REF: i believe it costs about ten dollars
# HYP: i believe it cost about ten dollars
#
# REF: what in the world drugs are you on to
# HYP: what in the wild dogs are you on to
#
# REF: android tv box
# HYP: android tv box
#
# REF: a couple of times
# HYP: a couple of times
#
# REF: i had the brakes done on it
# HYP: i had the back down on it
#
# REF: which i use as a reference and has been real handy
# HYP: what i see as a swift and has been really fun
#
# REF: i know when i was working
# HYP: so when i was working
#
# REF: it's a package deal
# HYP: it's a package deal
#
# REF: i have seen it
# HYP: i have seen it
#
# REF: the measures already passed a senate committee
# HYP: the measure already passed a senate committee
#
# REF: they told me that this was a topic
# HYP: they told me that this was a topic
#
# REF: in the red square or wherever said
# HYP: in the red cross or weaver said
#
# REF: they did a lot of play work and stuff
# HYP: they did a lot of play work and stuff
#
# REF: you can gain too much weight
# HYP: you can gain too much weight
#
# REF: recent legislation
# HYP: recent legislation
#
# REF: i'm a car buff too
# HYP: i'm a car buff to
#
# REF: joy springs from a grateful heart
# HYP: le pen from a grateful heart
#
# REF: char onion over grill never allow oil to smoke
# HYP: to win over real never a while to sink
#
# REF: noise causes air pollution
# HYP: you could cause air pollution
#
# REF: and then you sprinkle the cheese on top of that
# HYP: and then you sprinkle the cheese on top of that
#
# REF: just saying that clear vision is a necessity
# HYP: just saying that their vision is a necessity
#
# REF: factors that affect earnings of an employee
# HYP: factors that affect earnings of an employee
#
# REF: if you drink a lot of caffeine you'll stay awake
# HYP: if you drink a lot of caffeine will see work
#
# REF: that's a nice car
# HYP: that's a nice car
#
# REF: visionary leaders
# HYP: visionary leaders
#
# REF: the only other place i've ever vacationed
# HYP: the only other place of every occasion
#
# REF: i just kind of went through
# HYP: i just kind of went through
#
# REF: this is unifying voice we need
# HYP: this is anything but we need
#
# REF: do you have your bag
# HYP: do you have your bag
#
# REF: so you know it keeps us pretty busy
# HYP: so you know it keeps us pretty busy
#
# REF: that's a science in itself
# HYP: that's a sign in itself
#
# REF: so when you get in tight situations
# HYP: so when you get in tight situations
#
# REF: i can relate to that
# HYP: i can relate to that
#
# REF: it's all ready quit playing
# HYP: it's all really quit playing
#
# REF: if they're around anymore
# HYP: if they're around anymore
#
# REF: i am not even aware that i could have seen it
# HYP: i am not even aware that i could have seen it
#
# REF: the ranks of asian riders are swelling too
# HYP: the ranks of asian buyers are willing to
#
# REF: einstein equation
# HYP: einstein's equation
#
# REF: most points at the end wins
# HYP: most points at the end wins
#
# REF: i think it's one hundred and eighty miles
# HYP: i think it's one hundred and eighty miles
#
# REF: we don't usually take the kids when we go there
# HYP: we don't usually take the lead when we go there
#
# REF: one of those generation novels
# HYP: one of those generation models
#
# REF: they 'll never get caught
# HYP: will never get caught
#
# REF: i don't buy the newspaper
# HYP: i don't buy the newspaper
#
# REF: bringing something for a potluck picnic
# HYP: ranking system for a potluck picnic
#
# REF: i 'll take it out
# HYP: i'll take it out
#
# REF: improved evasion does not work
# HYP: improved vision does not work
#
# REF: casualties were reported
# HYP: casualties were reported
#
# REF: you just like to sit down and watch it
# HYP: you just like to sit down and watch it
#
# REF: he helps by giving little pointers
# HYP: he helps by giving little point
#
# REF: cause they all grew up in new york city
# HYP: they all grew up in new york city
#
# REF: you make such a choice
# HYP: you make such a choice
#
# REF: but they have snakes over there
# HYP: but they have sex over there
#
# REF: a good positive direction
# HYP: a good positive direction
#
# REF: that's what i was going to point out
# HYP: that's what i was going to point out
#
# REF: i turned mine in about twelve hours early at noon
# HYP: i turned mine in about twelve hours early at noon
#
# REF: it's a telecommunications type of company
# HYP: it's a validation type of company
#
# REF: i work out of my home
# HYP: i work out of my home
#
# REF: the way it works
# HYP: the way it works
#
# REF: it doesn't have an air conditioner
# HYP: it doesn't have an air conditioner
#
# REF: then you have to make a salad
# HYP: then you have to make a salad
#
# REF: solving the variables in the equation
# HYP: loving the visible in the equation
#
# REF: i read in the paper
# HYP: i read it in the paper
#
# REF: i'm in the speech processing business
# HYP: i'm in the peace process in business
#
# REF: once every year or two
# HYP: once every year or two
#
# REF: you don't eat it at all
# HYP: you don't eat it at all
#
# REF: twelve men tried and true
# HYP: i've been tried and true
#
# REF: i think that's something we might want
# HYP: i think that's something we might want
#
# REF: she thought for a few minutes
# HYP: she thought for a few minutes
#
# REF: that is a sad situation
# HYP: that is a sad situation
#
# REF: they do have capital punishment
# HYP: they do have capital punishment
#
# REF: it was nice talking to you dudley
# HYP: it was nice talking to you shortly
#
# REF: my favorite team is the rangers
# HYP: my favorite team is the rangers
#
# REF: kind of goes along with what you were saying
# HYP: kind of goes along with what you were saying
#
# REF: why they don't go with fourteen one
# HYP: but they don't go with part one
#
# REF: reader's choice award
# HYP: readers' choice award
#
# REF: they are the detroit delegates
# HYP: they are the detroit delegates
#
# REF: he went to vietnam one man and came back another
# HYP: i want to blame one man and come back another
#
# REF: as any city grows up
# HYP: as any city grows up
#
# REF: so you did buy a pattern
# HYP: so you did by a pattern
#
# REF: it's about sixteen and a half percent
# HYP: it's about six and a half percent
#
# REF: i agree with the phone
# HYP: i agree with the phone
#
# REF: so i think it's going to be a lot easier
# HYP: so i think it's going to be a lot easier
#
# REF: not too much soy sauce
# HYP: not too much soy sauce
#
# REF: we take a certain portion of your paycheck
# HYP: we take a certain portion of your pick
#
# REF: who sponsors you
# HYP: he passes you
#
# REF: and i don't know what's going to happen
# HYP: and i don't know what's going to happen
#
# REF: i think we have about thirteen months left on it
# HYP: i think we have about turning point they've done it
#
# REF: i do particularly find it annoying
# HYP: i do particularly find it annoying
#
# REF: they have clubs and a swimming pool
# HYP: they have cubs and a swimming pool
#
# REF: our point of view
# HYP: our point of view
#
# REF: it really is worth while to sew
# HYP: it really is worth while to go
#
# REF: i felt that was a little insensitive
# HYP: i felt that was a little incentive
#
# REF: public transportation
# HYP: public transportation
#
# REF: focal point
# HYP: focal point
#
# REF: i tried one on and was disappointed
# HYP: i turned on and on sept
#
# REF: what are we doing
# HYP: what are we doing
#
# REF: my job tends to be very demanding
# HYP: my job and to be very demanding
#
# REF: you know it was just in jest
# HYP: you know it was just in jest
#
# REF: and most people like that are old
# HYP: and most people like that are sold
#
# REF: that's what i was doing before
# HYP: that's what i was doing before
#
# REF: the best teachers and the best students
# HYP: the best kickers in the best students
#
# REF: i don't like it cold
# HYP: i don't like it cold
#
# REF: she was inaugurated in january
# HYP: she was inaugurated in january
#
# REF: wait a minute
# HYP: wait a minute
#
# REF: those are no good anymore
# HYP: those are no good anymore
#
# REF: i do want to have a raised bed
# HYP: i do want to have a raised bed
#
# REF: i say that but yet i know too
# HYP: i say that but that i know too
#
# REF: it wasn't organized enough for me
# HYP: it wasn't organized enough for me
#
# REF: if i don't know the story line
# HYP: if i don't know the story line
#
# REF: that i've liked in the past
# HYP: it's of lakes in the past
#
# REF: your spam my treasure
# HYP: your time my pleasure
#
# REF: he had choices to make the counselor told him
# HYP: he had choices to make the counselor told him
#
# REF: the last time he came was in march
# HYP: the last time he came was in march
#
# REF: i'm getting pretty
# HYP: i'm getting pretty
#
# REF: it's really a cost
# HYP: it's really a cost
#
# REF: have little material luxury but want a lot more
# HYP: have little bit longer but one a lot more
#
# REF: you guys really are newlyweds
# HYP: you guys really are delayed
#
# REF: we've got a stone from austin
# HYP: we've got a sign from my son
#
# REF: competition with japan
# HYP: competition with japan
#
# REF: it still makes most of its profit in asia
# HYP: it still makes most of its life in asia
#
# REF: i think that is important too
# HYP: i think that is important too
#
# REF: have a good evening
# HYP: have a good evening
#
# REF: unfortunately we tend to make these equations
# HYP: finally we can to make this occasion
#
# REF: he didn't eat flies
# HYP: i didn't eat flies
#
# REF: most of the time they don't bother with it
# HYP: most of the time they don't bother with it
#
# REF: they didn't strip it so i got it back
# HYP: they didn't keep it so i got it back
#
# REF: i'm sure all the eggs are in it
# HYP: i'm sure all the eggs are in it
#
# REF: the family issues that get discussed
# HYP: the family is that get discussed
#
# REF: a lot of the industry's moving southward
# HYP: a lot of the country's mood soured
#
# REF: when disclosure isn't enough
# HYP: when disclosure isn't enough
#
# REF: contact points
# HYP: contact points
#
# REF: this morning it was twenty nine
# HYP: this meant it was twenty nine
#
# REF: satan rejoiced with his birth
# HYP: season riddled with his birth
#
# REF: they fell out because of the drug issue
# HYP: they feel hurt because of the drug issue
#
# REF: these are done with a flour tortilla
# HYP: these are done with a flower to
#
# REF: don't collect unemployment
# HYP: don't take advantage
#
# REF: that is realistic for some people
# HYP: that is usually for some people
#
# REF: i'm away from my other son during those hours
# HYP: i'm away from my other son during those hours
#
# REF: where do you have to do a whole bunch of work
# HYP: where do you have to do a whole bunch of work
#
# REF: i take it she was an accountant
# HYP: i take it she was an account
#
# REF: go to a trip through the indonesian
# HYP: go to a trip for the nations
#
# REF: no problem there at all
# HYP: no problem there at all
#
# REF: their way of life changed
# HYP: the way of life ends
#
# REF: pass me that joint bank account statement
# HYP: let me that joint bank account statement
#
# REF: filters for air filtration for hospitals
# HYP: filter for eye irritation for hospitals
#
# REF: i do that when we travel
# HYP: i do that when we travel
#
# REF: i only saw the end of the first quarter
# HYP: i only saw the end of the first quarter
#
# REF: is there work to support this conclusion
# HYP: is the work to support this conclusion
#
# REF: buy a sewing machine
# HYP: by a certain mission
#
# REF: as soon as we get this house finished
# HYP: as soon as we get their house visit
#
# REF: and just keep chipping away at the ice
# HYP: and just keep chipping away at the us
#
# REF: all the money
# HYP: all the money
#
# REF: my husband has a tool shed out back
# HYP: my husband has a tool shed out back
#
# REF: certain kinds of sin
# HYP: what kind of scene
#
# REF: i always threaten my daughters with time-out
# HYP: i always thought in my daughters with come out
#
# REF: north korea is still allowed to receive oil
# HYP: north korea is still allowed to receive oil
#
# REF: let's see about getting parents more involved
# HYP: let's see about getting paid more involved
#
# REF: pass me that joint bank account statement
# HYP: give me that joint bank account statement
#
# REF: what you need is a tougher punishment regime
# HYP: what you need is a tougher punishment regime
#
# REF: so it was really too late to do much
# HYP: so it was really too late to do much
#
# REF: i wanted to go to that golf course down south
# HYP: i want to go to that golf course down south
#
# REF: you get a little taste of it and you say no
# HYP: you get a little taste of it and you say no
#
# REF: they don't even check my social security number
# HYP: they don't even take my story relating them
#
# REF: chicago and philadelphia
# HYP: chicago and philadelphia
#
# REF: i don't know if you have ever heard of it
# HYP: i don't know if you have ever heard of it
#
# REF: social arbitrage
# HYP: social robots
#
# REF: that's exactly the way he feels
# HYP: that's exactly the way he feels
#
# REF: do you really not remember
# HYP: do you really not remember
#
# REF: it am enjoying that side of it
# HYP: it has enjoyed that side of it
#
# REF: the ranks of asian riders are swelling too
# HYP: the ranks of asian buyers are willing to
#
# REF: the mission will draw the corresponding conclusions
# HYP: the mission will store the current conclusions
#
# REF: burials usually happen during the morning
# HYP: people really happened during the morning
#
# REF: be kind to your whole self
# HYP: be kind to your whole self
#
# REF: that's the other bar that we went to that night
# HYP: that's the other four that we went to that night
#
# REF: i don't know why
# HYP: i don't know why
#
# REF: you can fake sex love explosions special effects horror
# HYP: you can fix stack of explosions benefits here
#
# REF: he's in first grade now
# HYP: he's in first grade now
#
# REF: i guess there's some companies that aren't growing fast enough
# HYP: i guess to some companies that aren't growing fast enough
#
# REF: increasingly democratically oriented
# HYP: instantly domestically and
#
# REF: something a little extra
# HYP: seems a little extra
#
# REF: i kind of wish that they had a little league for the boys
# HYP: i kind of wish that they had a little like for the boys
#
# REF: killer bee instinct
# HYP: killer bee in six
#
# REF: i hadn't heard about that
# HYP: i hadn't heard about that
#
# REF: the ability of people to access healthcare
# HYP: the ability of people to access healthcare
#
# REF: that's probably one of the reasons
# HYP: that's probably one of the reasons
#
# REF: quite a few movies are based off of that
# HYP: quite a few movies are based off of that
#
# REF: but when i went home that's all i could think about
# HYP: but when i went home that's all i could think about
#
# REF: i'm north of that actually
# HYP: i'm more of that actually
#
# REF: a commercial project on hair conditioner
# HYP: a committee working on here under
#
# REF: it was something easy i could do
# HYP: it was something as i could do
#
# REF: i think that's why a lot of people go to west virginia
# HYP: i think was a lot of people go to west virginia
#
# REF: brown and black patches of fur
# HYP: brown and black patches of fur
#
# REF: the jury is expected to announce its decision
# HYP: the jury is expected to announce its decision
#
# REF: summary points
# HYP: some point
#
# REF: i don't get to watch
# HYP: i don't get to watch
#
# REF: it's all money now
# HYP: all been there
#
# REF: help promote that more
# HYP: how is that more
#
# REF: developing everything
# HYP: but everything
#
# REF: they're probably doing it to their benefit
# HYP: they probably do it to their business
#
# REF: that is good that they're like that
# HYP: that is good that they're like that
#
# REF: there is some definite snark in her report
# HYP: there is some definite stake in her report
#
# REF: i remember difficult times in school being behind on work
# HYP: i made a time in calling and by on work
#
# REF: the new york catholic conference blasted the measure
# HYP: the new york hacker does lead the way
#
# REF: when we were in high school it was always fun
# HYP: when we were in high school it was always fun
#
# REF: she knows how to do that
# HYP: you know how to do that
#
# REF: are you going to go see the elixir of love
# HYP: are you going to go see the act of love
#
# REF: i'm sure there are some
# HYP: i'm sure there are some
#
# REF: that's kind of like what we'd like to do
# HYP: that kind of like what we'd like to do
#
# REF: quite a lot of variety
# HYP: quite a lot of beauty
#
# REF: i haven't been to a baseball game in years
# HYP: i haven't been to a baseball game in years
#
# REF: parents aren't parents any more
# HYP: france and britain any more
#
# REF: a dressing of oil and vinegar
# HYP: a diet of early and middle
#
# REF: it just kind of dragged on forever
# HYP: it just kind of dragged on forever
#
# REF: that's the only way you can get to canada from here
# HYP: that's the only way you can get to canada from here
#
# REF: he shot a career low
# HYP: he got a very low
#
# REF: here are the choicest excerpts from the draft
# HYP: here are the states act from the left
#
# REF: i have to think about it some more now
# HYP: i have to think about it some more now
#
# REF: i was really kind of excited to start reading
# HYP: i was really kind of excited to start reading
#
# REF: what are you saying
# HYP: what are you sane
#
# REF: that's very interesting
# HYP: for instance
#
# REF: i enjoyed it very much
# HYP: i enjoyed it very much
#
# REF: he had occasionally sent her mother money
# HYP: he had occasion in her mother money
#
# REF: an earlier version of this article
# HYP: an earlier version of this article
#
# REF: you might even be able to get a job there
# HYP: you might even be able to get a job there
#
# REF: enjoyable to use
# HYP: unable to use
#
# REF: we came to a fork in the road at night
# HYP: we came to a fork in the woods at night
#
# REF: he really likes it and i don't
# HYP: he really liked it and i don't
#
# REF: it's nice and small
# HYP: it's nice and small
#
# REF: i think there is confusion
# HYP: i think there is confusion
#
# REF: just go someplace for the day
# HYP: the new campus for the day
#
# REF: but they're going to learn it sometime
# HYP: but they're going to learn it sometimes
#
# REF: it was the big one
# HYP: it was the big one
#
# REF: it's kind of a depressing topic
# HYP: it's kind of a in public
#
# REF: every six months i have to pay my taxes
# HYP: every statement i have to pay my taxes
#
# REF: i've never been sailing
# HYP: i've never been stolen
#
# REF: i have six years of college
# HYP: i have six years of college
#
# REF: and then the next one down is in the marines
# HYP: and then the next one down is in the period
#
# REF: enjoy the adventure
# HYP: enjoy the day
#
# REF: not lately though
# HYP: not really low
#
# REF: too many serious problems for the longer term
# HYP: too many serious problems for the long term
#
# REF: are there any other genres or sounds you're interested in exploring
# HYP: are there any other country or send your instant in exploiting
#
# REF: yes i consider myself what they call a full timer
# HYP: this i can't miss what they call a full summer
#
# REF: more family oriented
# HYP: more family oriented
#
# REF: do you know that i've never seen a monkey
# HYP: do you know that i've never seen a monkey
#
# REF: i knew both people
# HYP: i know both people
#
# REF: he recommends the honda to a lot of people
# HYP: i recommend the hunter to a lot of people
#
# REF: do you have a computer for yourself at home
# HYP: do you have a sense for yourself at home
#
# REF: it's the original
# HYP: it's the originals
#
# REF: you can't blame them
# HYP: you can't blame them
#
# REF: more choice more cccountability
# HYP: more choice for cannibals
#
# REF: i guess traffic could be an annoyance
# HYP: i guess traffic could be an annoyance
#
# REF: we've gone for romanian food and lebanese food
# HYP: we've got four remaining food and service roads
#
# REF: i hate to dust and clean
# HYP: i had to dust and king
#
# REF: football is an exciting sport
# HYP: football is an exciting part
#
# REF: i'm glad it's done
# HYP: i'm glad it's done
#
# REF: i don't know the details
# HYP: i don't know the details
#
# REF: can you speak more about this system of treasury decentralization
# HYP: when you make more about this season of salary inflation
#
# REF: too many horror stories out there
# HYP: so many horror stories out there
#
# REF: every major city has a theater
# HYP: every major city as a leader
#
# REF: go to the zoo and see elephants and tigers and things like that
# HYP: go to the two and two elephants and dogs and things like that
#
# REF: it'd be kind of fun
# HYP: it was kind of one
#
# REF: that appeared to be eight or nine years old
# HYP: that appeared to be eight or nine years old
#
# REF: i'm kind of out of it right now
# HYP: i'm kind of out of it right now
#
# REF: i do not read everything in the paper
# HYP: i don't get rid of things in the report
#
# REF: my brother can do it
# HYP: i really can do it
#
# REF: not everybody shows up
# HYP: not everybody showed up
#
# REF: americans have pushed them out of their native land
# HYP: americans have put them out of their native lands
#
# REF: it was just based on the facts
# HYP: it was just been on the facts
#
# REF: wasn't it your state that had police involvement
# HYP: when it was steak that had placed involved
#
# REF: did you actually use drugs at all
# HYP: did you like to drink at all
#
# REF: i don't have too much either
# HYP: i don't have too much there
#
# REF: i can finish it in a day
# HYP: i can fit it in a day
#
# REF: very well persuaded
# HYP: we will spend
#
# REF: little jam box
# HYP: the same box
#
# REF: the tree were so poignant
# HYP: the key was to present
#
# REF: i'm wearing shorts
# HYP: i'm running short
#
# REF: do you have some vacation time
# HYP: you have some prison time
#
# REF: where did you get this cook book
# HYP: where did you get this look back
#
# REF: vision in the cave of evil
# HYP: rise in the face of evil
#
# REF: without the visual it's meaningless
# HYP: but the people it is
#
# REF: i'll try that next week
# HYP: i'll try that next week
#
# REF: we do as a matter of fact
# HYP: we do as a matter of weeks
#
# REF: i have some games
# HYP: i have some games
#
# REF: we're going to feel it watch out
# HYP: we're going to feel it works out
#
# REF: the news is a good way to keep up to date
# HYP: the news is a good way to keep up to date
#
# REF: point blank in the face
# HYP: point blank in the face
#
# REF: just walking the streets
# HYP: just walking the streets
#
# REF: he did not want to be in it any more than i did
# HYP: he did not want to be in it any more than i did
#
# REF: the teacher had eleven kids
# HYP: the texans had seven kids
#
# REF: we were promised civil liberties
# HYP: we were promised civil liberties
#
# REF: click here to join freelancer
# HYP: click here to join finance
#
# REF: knowledge or insight into politics
# HYP: the war ended in politics
#
# REF: don't let them see violence at home
# HYP: don't let them see violence at home
#
# REF: the issue is that your employer is going under
# HYP: the issue is that you simply is going on
#
# REF: what do you write for them
# HYP: what do you write for them
#
# REF: our point of view
# HYP: our point of view
#
# REF: the lot we lived on is now a ranch
# HYP: the that we live in is now a chance
#
# REF: for your next vehicle do you want a truck
# HYP: for your next vehicle do you want a week
#
# REF: it's all traditional cooking
# HYP: it's all original token
#
# REF: they pass your phone number on to another company
# HYP: they put your phone number on to another company
#
# REF: they had sixty four of them
# HYP: they had taken four of them
#
# REF: well i liked the seventies
# HYP: where i like the center
#
# REF: this is fusion as liberation
# HYP: this is vision as liberation
#
# REF: it's probably going to be a very old used one
# HYP: it's probably going to be a real old news on
#
# REF: enjoy your day
# HYP: enjoy your day
#
# REF: the mental capacity to raise them
# HYP: the middle east to raise them
#
# REF: friday afternoon at five thirty
# HYP: brady isn't it lovely
#
# REF: lawmakers passed a measure last year
# HYP: lawmakers passed a measure last year
#
# REF: i mean a large flat plate
# HYP: i mean a large flat plate
#
# REF: i'd like to see it be more of an amateur sport
# HYP: i'd like to see it be more of an indoor sport
#
# REF: all of our tin cans
# HYP: all of our tin cans
#
# REF: praying more often than usual
# HYP: praying more often than usual
#
# REF: capital punishment
# HYP: capital punishment
#
# REF: everyone knows they're going to get it
# HYP: everyone knows they're going to get it
#
# REF: my in laws listen to the kind of music i hate
# HYP: my in a listen to the kind of music it
#
# REF: download on your computer or television
# HYP: download on your computer or television
#
# REF: and we play out here in the summertime
# HYP: and we play out here in the summertime
#
# REF: it never did run right again
# HYP: it never does one write again
#
# REF: you are frequently exploited
# HYP: you are fully deployed
#
# REF: especially the ones that came out and said their piece
# HYP: especially the ones that came out and said the place
#
# REF: pay and exhaustion and you know
# HYP: we are excited to you know
#
# REF: where another one won't
# HYP: we love and want
#
# REF: former employers
# HYP: former employees
#
# REF: it looks like they've got a weapon
# HYP: it looks like they've got a weapon
#
# REF: but you don't know that
# HYP: but you don't know that
#
# REF: i noticed something interesting last time
# HYP: i notice something in one last time
#
# REF: they wouldn't have to
# HYP: they won't have to
#
# REF: do you go like home cooking
# HYP: do you just like home cooking
#
# REF: so it seems to be
# HYP: so it seems to be
#
# REF: the decision to censor the articles
# HYP: the decision to censor the article
#
# REF: special rules for employment cases
# HYP: that's all for employment cases
#
# REF: it would just depend
# HYP: it would just depend
#
# REF: i like ice skating
# HYP: i like this setting
#
# REF: they've got the full weight room
# HYP: they've got the full weight room
#
# REF: you had to have a supply
# HYP: you had to have a pool
#
# REF: that's neat that you like cross stitching also
# HYP: that said that you like christina hall
#
# REF: the measure now heads to goverment
# HYP: the money i had to happen
#
# REF: my three year old
# HYP: my three year old
#
# REF: just not feasible you know
# HYP: there's not people you know
#
# REF: i can't really think of anything else offhand
# HYP: i can't really think of anything is fine
#
# REF: i'm not sure how to go about it
# HYP: i'm not sure how to go about it
#
# REF: it's very tedious if you don't have a whole group
# HYP: it's very tedious if you have a whole group
#
# REF: it was a cordless phone
# HYP: it was a cordless phones
#
# REF: but it's kind of hard
# HYP: but it's kind of hard
#
# REF: you can do so much with them
# HYP: you can do so much with them
#
# REF: my skill set got diminished by the steroid
# HYP: my skill set got diminished by the sword
#
# REF: it was like four hundred times as much
# HYP: it was like four hundred times as much
#
# REF: it's beautifully done
# HYP: it's probably done
#
# REF: i would feel that i had the right to
# HYP: i would feel that i had the right to
#
# REF: you just call him direct
# HYP: you just call him tracks
#
# REF: i know there is
# HYP: i know the is
#
# REF: it really hurts me
# HYP: it really hurts me
#
# REF: the experience
# HYP: the experience
#
# REF: do we have to wait until all the land fills
# HYP: you have to wait until all the land sale
#
# REF: really scary to me
# HYP: very clear to me
#
# REF: i think it is getting worse
# HYP: i think it is getting worse
#
# REF: i really would like to see them do well
# HYP: we would like to see them too well
#
# REF: i don't live in a house
# HYP: i don't live in a house
#
# REF: people put them in
# HYP: people put them in
#
# REF: it can swim away fast enough and go hide
# HYP: it can seem very fast enough and go hide
#
# REF: for about two hundred dollars
# HYP: for about two hundred dollars
#
# REF: in that time frame
# HYP: in that time frame
#
# REF: trying to make it through that
# HYP: trying to make it through that
#
# REF: anything like that we participated
# HYP: anything like that we detected
#
# REF: seven years in the pros
# HYP: seven years in the u
#
# REF: twenty years or so
# HYP: many days or so
#
# REF: i think it does help
# HYP: i think it does help
#
# REF: that has got to be blooming this time of year
# HYP: that has got to be coming this time of year
#
# REF: even these buses
# HYP: even the most
#
# REF: take your sick leave
# HYP: take your sick leave
#
# REF: it's been kind of scary
# HYP: it's been kind of story
#
# REF: the leaves are just dead
# HYP: the leaves are just said
#
# REF: we try to go so often
# HYP: we try to go so often
#
# REF: it took four days
# HYP: it took four days
#
# REF: the pros and cons of both
# HYP: the pros and cons of both
#
# REF: were thoroughbreds
# HYP: we're so bad
#
# REF: you get programming
# HYP: you get from camden
#
# REF: not that i like reading
# HYP: not that i like writing
#
# REF: i think a cup or two
# HYP: i think a cup or two
#
# REF: i don't mean to be knocking
# HYP: i don't mean to be talking
#
# REF: i'd like to see those
# HYP: i'd like to see those
#
# REF: a controlled substance
# HYP: a controlled substance
#
# REF: we're real close
# HYP: will close
#
# REF: i guess he's trained in this
# HYP: i get to stand on this
#
# REF: it might be kind of scary
# HYP: it might be kind of cheeky
#
# REF: perhaps not in the manner that we do it
# HYP: perhaps not in the manner that we do it
#
# REF: do you have friends with older children
# HYP: do you have friends with older children
#
# REF: one had more blue to it
# HYP: one had more feel to it
#
# REF: i just file federal income tax every year
# HYP: i just file federal income tax every year
#
# REF: i grew up on a farm
# HYP: i grew up on a farm
#
# REF: that was the one that's been really nice to have
# HYP: that was the one that's been really nice to have
#
# REF: they've done it before
# HYP: they've done it before
#
# REF: the engine was pretty good
# HYP: the end was pretty good
#
# REF: how different the people there really are
# HYP: how different the people there really are
#
# REF: we get out on the water occasionally
# HYP: we get out on the water occasionally
#
# REF: maybe once every quarter or so
# HYP: maybe once every call or so
#
# REF: since brian was born
# HYP: that line was born
#
# REF: i make that once in a while
# HYP: i made that once in a while
#
# REF: how to do things
# HYP: how to do things
#
# REF: i typically am not a cat person
# HYP: i typically am not a cat person
#
# REF: the junk mail that you get
# HYP: the like me that you get
#
# REF: they put him in the nurse's office
# HYP: they put him in the nurse's office
#
# REF: since this time last year i've changed
# HYP: since this time last year of change
#
# REF: they didn't fight together
# HYP: they didn't put together
#
# REF: he seemed to know what he was doing
# HYP: i seem to know what he was doing
#
# REF: they just live in the community
# HYP: they just live in the company
#
# REF: it had to be november anyway
# HYP: it had to be different anyway
#
# REF: if you do decide to go with child care
# HYP: if you do decide to go with child care
#
# REF: does insurance pay for the body damage
# HYP: the insurance pay for the body damage
#
# REF: one is eight and one is eleven
# HYP: one is eight and one is eleven
#
# REF: i was drug tested
# HYP: i was drug tested
#
# REF: newer neighborhoods and development communities
# HYP: drew estate and development companies
#
# REF: they are going to get a gun no matter what
# HYP: they are going to get a gun no matter what
#
# REF: when i was in high school we had a choice
# HYP: when i was in high school we had a choice
#
# REF: never painted the outside
# HYP: never found the it is
#
# REF: that's how we got started
# HYP: that's how we got started
#
# REF: a nicer desk than i could afford
# HYP: a nicer gift than i could avoid
#
# REF: it's really beautiful
# HYP: it's really beautiful
#
# REF: most people aren't
# HYP: more people want
#
# REF: i think what they will do is start paying mexico
# HYP: i think what they will do is start paying back
#
# REF: i haven't experienced it
# HYP: i haven't experienced it
#
# REF: you have to have a pretty good frame
# HYP: you have to have a pretty good team
#
# REF: those small little trucks and cars like that
# HYP: there's so little trucks and cars like that
#
# REF: they don't have the ability to develop it
# HYP: they don't have the ability to develop it
#
# REF: you got to have a one tenth indicator
# HYP: you got to have a one month later
#
# REF: there's so much going on here
# HYP: there's so much going on here
#
# REF: the victims' families and things
# HYP: the victims' families and things
#
# REF: being one of these late in life mothers
# HYP: being one of these steps in life mother
#
# REF: the drug dealers
# HYP: the drug dealers
#
# REF: my wife's mother is the only grandparent left
# HYP: my wife's mother is the only endpoint life
#
# REF: they're grown now
# HYP: they're gone now
#
# REF: i have never skied before
# HYP: i have never had before
#
# REF: i don't know what we're going to do
# HYP: i don't know what we're going to do
#
# REF: it's second nature
# HYP: it's second nature
#
# REF: find out where the languages are
# HYP: find out where the links are
#
# REF: we don't get to see too many
# HYP: we don't get to see too many
#
# REF: it's like a bullet going by
# HYP: it's like a bullet going by
#
# REF: i mean lunch today was eighteen dollars
# HYP: i mean like today was eighteen dollars
#
# REF: it's really unfortunate
# HYP: it's really unfortunate
#
# REF: the next morning you want to take them out
# HYP: the next morning you want to take them out
#
# REF: if the news we're getting is any good
# HYP: if the new we're getting is any good
#
# REF: if something goes wrong
# HYP: if something goes wrong
#
# REF: i haven't seen any
# HYP: i haven't seen any
#
# REF: used to chase each other all through the house
# HYP: how to teach each other all through the house
#
# REF: you don't worry about them too much
# HYP: you don't worry about them too much
#
# REF: that kind of gas mileage
# HYP: that kind of gas mileage
#
# REF: it really doesn't make any difference
# HYP: it really doesn't make any difference
#
# REF: i was born in texas and i visited other areas
# HYP: i was one in six and a friend of theirs
#
# REF: i guess because i work quite a bit with lawyers
# HYP: i guess because i work quite a bit with lower
#
# REF: i guess i haven't had that much experience
# HYP: i guess i haven't had that much experience
#
# REF: reports and papers and that sort of thing
# HYP: reports and papers and that sort of thing
#
# REF: spending money that does not belong to them
# HYP: training mode that does not belong to them
#
# REF: does it have to be a special color
# HYP: does it have to be a special color
#
# REF: that's the freedom of choice
# HYP: that's the freedom of choice
#
# REF: i don't know too much about it
# HYP: i didn't know too much about it
#
# REF: my son plays football
# HYP: my son plays football
#
# REF: see how the family liked it
# HYP: see how the family liked it
#
# REF: one's in college already
# HYP: one in college years
#
# REF: were his civil rights violated
# HYP: his civil rights violated
#
# REF: it looks like it would be
# HYP: it looks like it would be
#
# REF: doing laundry by hand and that kind of thing
# HYP: doing laundry by hand and that kind of thing
#
# REF: i don't want stubs in my lawn
# HYP: i don't want stop in my line
#
# REF: we can keep that out of our minds
# HYP: we can keep that out of our minds
#
# REF: forms for his photography business
# HYP: from for his country since
#
# REF: we are seeing that here as well
# HYP: we are seeing that here as well
#
# REF: that's what made me happy
# HYP: that's what made me happy
#
# REF: it depends on the person
# HYP: it depends on the person
#
# REF: i don't make that much
# HYP: i don't make that much
#
# REF: it's been a long time
# HYP: it's been a long time
#
# REF: no one can drive on ice
# HYP: no one can live on ice
#
# REF: maybe they based it on that mister mom movie
# HYP: maybe they missed out on that measure from movie
#
# REF: it seems like they would be able to
# HYP: it seems like they would be able to
#
# REF: just didn't fit the car
# HYP: just didn't find the car
#
# REF: she's one of those that loves
# HYP: she's one of those that love
#
# REF: now i just have to finish it though
# HYP: now i just have to face it though
#
# REF: mostly with adolescents
# HYP: mostly with silence
#
# REF: i'm not a carpenter or anything like that
# HYP: i'm not a company or anything like that
#
# REF: i like to listen to piano music a whole lot
# HYP: i like to listen to piano music a whole lot
#
# REF: two hour classes
# HYP: to our class
#
# REF: basically adults
# HYP: basically a lot
#
# REF: so you enjoy camping
# HYP: do you enjoy camping
#
# REF: it's kind of a show piece
# HYP: it's kind of a show piece
#
# REF: ambiance down there
# HYP: what's down there
#
# REF: how do you like your tread mill
# HYP: how do you like your trade bill
#
# REF: it was just too perfect at all times
# HYP: it was just to speak at all times
#
# REF: their self identity is stronger
# HYP: their cell and is wrong
#
# REF: it is pretty okay
# HYP: it is pretty okay
#
# REF: i thought that that was what celery seed was for
# HYP: i thought that that was what really did was for
#
# REF: i couldn't get her up
# HYP: i couldn't get her up
#
# REF: was it six weeks old
# HYP: with its six weeks old
#
# REF: fifteen feet wide
# HYP: fifteen feet wide
#
# REF: or a bigger city
# HYP: you're a big city
#
# REF: fish chunks and dip it in the fondue
# HYP: we want and keep it in the fund
#
# REF: when you found out who it was
# HYP: when you find out who it was
#
# REF: because they bring guns to school
# HYP: because they bring going to school
#
# REF: they roll up
# HYP: they will up
#
# REF: have you ever been drug tested
# HYP: have you ever been drug tested
#
# REF: he could get hurt
# HYP: he could get hurt
#
# REF: i'm originally a texan
# HYP: i'm currently a token
#
# REF: so you've got a lot of traffic noise real close
# HYP: so you've got a lot of traffic going real slow
#
# REF: really enjoyed it quite a bit
# HYP: really doing it quite a bit
#
# REF: i know a girl
# HYP: i know a girl
#
# REF: you've got to eat most of the time
# HYP: we've got to eat most of the time
#
# REF: to the price of what i buy
# HYP: to the place of what a day
#
# REF: even in my case
# HYP: even in my case
#
# REF: can do whatever they want
# HYP: can do whatever they want
#
# REF: because you own it
# HYP: because you own it
#
# REF: a little more flexibility
# HYP: a little more flexibility
#
# REF: they even looked halfway decent
# HYP: they even like every distance
#
# REF: a food processor
# HYP: food prices
#
# REF: i think the decision has been made
# HYP: i think the decision has been made
#
# REF: they are not sure of themselves
# HYP: they are not sure of themselves
#
# REF: two sides of the same coin
# HYP: two sides of the same coin
#
# REF: he doesn't really pay attention
# HYP: he didn't really pay attention
#
# REF: if you're ever looking for that
# HYP: if you're ever looking for that
#
# REF: draw your own conclusions
# HYP: your own conclusions
#
# REF: that's from the child's standpoint
# HYP: that's from the child's some point
#
# REF: there is no timetable for a decision
# HYP: there is no timetable for a decision
#
# REF: golden retriever
# HYP: children receive
#
# REF: nurses get so worn down
# HYP: let's get to run down
#
# REF: the second time you see it
# HYP: you take time to see it
#
# REF: i mean you can earn a lot more money
# HYP: i mean you can learn a lot more money
#
# REF: but at that point i was too far gone
# HYP: but at that point i was too far gone
#
# REF: his voice was nearly drowned out by the crowd
# HYP: his voice was nearly drowned out by the kids
#
# REF: i didn't notice it
# HYP: i didn't know it
#
# REF: that was a great little car
# HYP: that was a great little car
#
# REF: over a very long period of time
# HYP: have a very long period of time
#
# REF: started investigating
# HYP: road investigation
#
# REF: vice presidents of companies
# HYP: the presence of companies
#
# REF: i wasn't opposed to paying for it
# HYP: i wasn't able to pay for it
#
# REF: to upholster chairs
# HYP: you also choose
#
# REF: they are lovely
# HYP: there are lovely
#
# REF: we see more and more women being involved
# HYP: we see more and more women being involved
#
# REF: i have to make this one last as long as i can
# HYP: i have to make this one last as long as i can
#
# REF: only to the airport
# HYP: on to the airport
#
# REF: well tell me this
# HYP: we'll tell me this
#
# REF: that would be really awful
# HYP: that would be really awful
#
# REF: question and answer period
# ...
#
# REF: i've had so many people
# HYP: i've had so many people
#
# REF: i don't even get to see half my paycheck
# HYP: i don't even get to see have my project
#
# REF: we put some papers on the floor
# HYP: we put some papers on the floor
#
# REF: that's the closest thing
# HYP: that's the closest thing
#
# REF: it's kind of rainy actually
# HYP: kind of funny actually
#
# REF: it was worth the buck i guess
# HYP: it was was the box i guess
#
# REF: a pop up trailer
# HYP: pop up trailer
#
# REF: you're with the home office now
# HYP: you with the home office now
#
# REF: they seem to be economically driven also
# HYP: they seem to be economically driven all
#
# REF: that would be a really good thing to do
# HYP: that be a really good thing to do
#
# REF: too much business
# HYP: too much business
#
# REF: he's retired now
# HYP: he's retired now
#
# REF: i heard this on a christian program
# HYP: i heard this on a christian program
#
# REF: even though they're so close
# HYP: even though they're too close
#
# REF: earning his money
# HYP: earning his money
#
# REF: i had never seen anything
# HYP: i had never seen anything
#
# REF: these rich people started
# HYP: this week people started
#
# REF: used to be six bucks
# HYP: used to be six bucks
#
# REF: i caught a carp
# HYP: i caught a group
#
# REF: i feel so silly
# HYP: i feel so silly
#
# REF: are they all here in the area
# HYP: are they all here in the air
#
# REF: i kind of look at it this way
# HYP: i kind of look at it this way
#
# REF: public broadcasting
# HYP: public parking
#
# REF: sewing and quilting
# HYP: sewing and quilting
#
# REF: good to hear from you
# HYP: good to hear from you
#
# REF: through oklahoma city
# HYP: their token sale
#
# REF: i read a lot and then i know people
# HYP: i read a lot and and i know people
#
# REF: did you pull them
# HYP: did you pull them
#
# REF: that would make me happy though
# HYP: that would make me happy too
#
# REF: it's nice to get out in the open air
# HYP: it's nice to get out in the open here
#
# REF: i think it would do something for it
# HYP: i think it would do something for it
#
# REF: it has really been nice here
# HYP: it has really been nice here
#
# REF: state land grant colleges
# HYP: said the grant dollars
#
# REF: it works out real nice
# HYP: it worked out real nice
#
# REF: we've had lots of them in the past
# HYP: i've had lots of them in the past
#
# REF: it's only been that way in the last five years
# HYP: it's only been that way in the last five years
#
# REF: i left right in the middle of it
# HYP: i left out in the middle of it
#
# REF: it's depressing too
# HYP: it's distressing to
#
# REF: i don't own my home
# HYP: i don't own my home
#
# REF: i've always wondered how he gets around
# HYP: i've always wondered how to get around
#
# REF: it's just tough
# HYP: it's just tough
#
# REF: fiction books that i really like
# HYP: fiction books that i really like
#
# REF: you got any more
# HYP: you got any more
#
# REF: i'm beginning to think it's not
# HYP: i'm beginning to think it's not
#
# REF: that's something i miss quite a bit
# HYP: that's something i missed quite a bit
#
# REF: they finally came up with evidence
# HYP: they finally came up with difference
#
# REF: that's true i didn't think about that
# HYP: that's true i didn't think about that
#
# REF: good together as a team
# HYP: good data as a team
#
# REF: part of it would probably work out
# HYP: part of it would probably work out
#
# REF: it's necessarily going to involve more taxes
# HYP: it's necessarily going to involve more taxes
#
# REF: it's just going to follow
# HYP: it's just going to hell
#
# REF: i'm kind of a car buff myself
# HYP: i'm kind of a car with myself
#
# REF: buying of our fish
# HYP: writing of a face
#
# REF: sometimes it will skip
# HYP: sometimes it will lapse
#
# REF: i just don't like that
# HYP: i just don't like that
#
# REF: social changes to talk about
# HYP: usually going to talk about
#
# REF: i am close to receiving my english degree
# HYP: i am close to return my english degree
#
# REF: everything's still inches
# HYP: everything to change
#
# REF: he made a real big cake himself
# HYP: he made a real big kick himself
#
# REF: they've actually waited for them
# HYP: the actual rate for them
#
# REF: it was for a murder trial
# HYP: it was for a murder trial
#
# REF: are you a professional musician
# HYP: are you a personal reasons
#
# REF: it's far beyond me
# HYP: it's far beyond me
#
# REF: we've gained an awful lot from the space program
# HYP: we've been an awful lot from the space program
#
# REF: two sets of grandparents
# HYP: two sets of conference
#
# REF: i call and find out
# HYP: i call and find that
#
# REF: you want salary too plus what
# HYP: you want sally to but what
#
# REF: i've heard about him
# HYP: i've heard about him
#
# REF: you've had more freezing this winter
# HYP: we've had more rain this winter
#
# REF: if we can't get a handle on that
# HYP: if we can't get a handle on that
#
# REF: they would vote pro choice
# HYP: they would vote for choice
#
# REF: they were okay
# HYP: they were ok
#
# REF: to find a mountain
# HYP: to find a button
#
# REF: on a working farm
# HYP: on a working time
#
# REF: after we had them for several years
# HYP: after we had them for several years
#
# REF: if they work at it a little bit
# HYP: if they work at it a little bit
#
# REF: we don't have enough
# HYP: we don't have enough
#
# REF: what are you making
# HYP: what are you making
#
# REF: absolutely nothing
# HYP: absolutely nothing
#
# REF: i had a carpet service call up three times
# HYP: i had a carpet service call up their time
#
# REF: although he's probably better than a lot of them
# HYP: although he's probably better than a lot of them
#
# REF: just about any kind of music
# HYP: just about any kind of music
#
# REF: we like mexican food
# HYP: we like mexican food
#
# REF: i know the day care centers are not cheap either
# HYP: i know the day care centers are not cheap either
#
# REF: i found it a lot of times
# HYP: i found it a lot of time
#
# REF: you've got to find an even line
# HYP: you've got to find and even line
#
# REF: i think he barely makes it
# HYP: i think he really makes it
#
# REF: where you cut the pie
# HYP: where you get the boys
#
# REF: it all starts to become similar
# HYP: it all starts to become similar
#
# REF: i could go along with that
# HYP: i could go along with that
#
# REF: it's like one second of recording
# HYP: it's like one second of recordings
#
# REF: that's a big thing with me
# HYP: that's a big thing with me
#
# REF: i'm the only one
# HYP: i'm the only one
#
# REF: i've been following through on that
# HYP: i've been following through on that
#
# REF: if there starts to be a lot of violence
# HYP: if they want to be a lot of balance
#
# REF: walking seems to be the best
# HYP: walking seems to be the best
#
# REF: i don't think too many of them are anymore
# HYP: i don't think too many of them are anymore
#
# REF: how do you feel about your game
# HYP: how do you feel about your game
#
# REF: when i lived out in the country
# HYP: when i left out in the country
#
# REF: i'm originally from maine
# HYP: i'm originally from maine
#
# REF: to grow up and to decide what they want to do
# HYP: to go up and to get what they want to do
#
# REF: we just keep track of it on paper
# HYP: we just keep sake of it on paper
#
# REF: i had friends
# HYP: i had friends
#
# REF: i've worked in hotels
# HYP: i've worked in hotels
#
# REF: they can pretty much get everybody there
# HYP: they can pretty much what everybody there
#
# REF: you can just say i'm sorry
# HYP: you can just say i'm sorry
#
# REF: the engine blew up in it
# HYP: the engine blew up in it
#
# REF: the armed forces did so much
# HYP: the armed forces is so much
#
# REF: i don't have a lot of time
# HYP: i don't have a lot of time
#
# REF: i know they will
# HYP: i know they will
#
# REF: sometimes they're not very open
# HYP: sometimes they're not very common
#
# REF: we're toward the bottom
# HYP: we store the bottom
#
# REF: i make a lot of my christmas presents
# HYP: i make a lot of my christmas presents
#
# REF: we were talking about that just the other day
# HYP: we were talking about that is the other day
#
# REF: in the houston area
# HYP: in the houston area
#
# REF: i'm not counting on it
# HYP: i'm not counting on it
#
# REF: i like to have somebody come with me
# HYP: i like to have somebody come with me
#
# REF: was also kind of tough
# HYP: was always kind of stuff
#
# REF: not sure that's something i want to do
# HYP: not sure that's something i want to do
#
# REF: most of the stores will accept those
# HYP: most of the story will keep those
#
# REF: that is pretty unusual
# HYP: that is pretty unusual
#
# REF: that's what he grew up listening to
# HYP: that's what he grew up listening to
#
# REF: she'll be two in july
# HYP: will be true in july
#
# REF: i just flat didn't spend any money
# HYP: i just get it in any money
#
# REF: the news or something
# HYP: the news or something
#
# REF: i do have my radio going most of the day though
# HYP: i do have my video going most of the day though
#
# REF: a girl and a boy
# HYP: gold and a b
#
# REF: he has used a lot
# HYP: he has used a lot
#
# REF: it's a little bit financial type thing
# HYP: it's a little bit final type thing
#
# REF: an economic incentive for people to vote
# HYP: an economic incentive for people to vote
#
# REF: i'm different from that
# HYP: i'm guessing from that
#
# REF: temperature swing in about four hours
# HYP: from here are your thing in about four days
#
# REF: what's going to happen
# HYP: what's going to happen
#
# REF: i only weigh sixteen today
# HYP: i only wear section c
#
# REF: horrible stuff like that
# HYP: horrible stuff like that
#
# REF: an opera or the symphony or something
# HYP: and up for the company or something
#
# REF: if they don't have any living relatives
# HYP: if they don't have any living relatives
#
# REF: i watch the news on tv
# HYP: i watched the news on tv
#
# REF: a record of the rap songs of the eighties
# HYP: workers of the tip line of the city
#
# REF: i do not have much to compare it to
# HYP: i do not have much to compare it to
#
# REF: i don't read as much as i would like to either
# HYP: i don't need as much as i would like to either
#
# REF: this was pasture land
# HYP: this was better than
#
# REF: i want them to come back up next year
# HYP: i want them to come back as much year
#
# REF: noticed that when i was a kid
# HYP: does that when i was a kid
#
# REF: things that are under state jurisdiction
# HYP: things that are under state restrictions
#
# REF: i was an administrator
# HYP: i was on merit
#
# REF: i don't have a lot of time to do it
# HYP: i don't have a lot of time to do it
#
# REF: when i'm up here
# HYP: and i'm up here
#
# REF: i enjoy them coming
# HYP: i enjoy them coming
#
# REF: but it has a pretty low crime rate
# HYP: but it was a pretty low crime rate
#
# REF: big closet space
# HYP: big closet space
#
# REF: they're welcome to go some place else
# HYP: we're willing to go some place else
#
# REF: i write software
# HYP: i write software
#
# REF: we do a lot of things on the weekends together
# HYP: we do a lot of things on the weekend together
#
# REF: i've heard different
# HYP: i've heard different
#
# REF: we'd have to build less prisons
# HYP: we'd have to build this reason
#
# REF: just light reading
# HYP: light reading
#
# REF: well we just started
# HYP: while we just started
#
# REF: we started taking her
# HYP: we started taking her
#
# REF: my mother and i were
# HYP: my mother and i were
#
# REF: we are so busy
# HYP: we are so busy
#
# REF: i'd like to go bird hunting
# HYP: i'd like to go bird hunting
#
# REF: sometimes you have to ask them for that
# HYP: sometimes you have to ask them for that
#
# REF: then do it all over again
# HYP: then do it all over again
#
# REF: what do you think are some current trends
# HYP: what do you think are some current trends
#
# REF: about a thousand bad checks
# HYP: but a distant land tax
#
# REF: do you watch star trek
# HYP: do you watch star trek
#
# REF: no you don't have to put it down
# HYP: so you don't have to put it down
#
# REF: i don't see much tv mostly when i'm in school
# HYP: i don't see much of mostly when i'm in school
#
# REF: they could probably come in and say
# HYP: they could probably come in and says
#
# REF: i don't get too many of those
# HYP: i don't get too many of those
#
# REF: did they do that before you went in or what
# HYP: that they do that by he went in or want
#
# REF: i'm getting rid of this car
# HYP: i'm getting rid of this car
#
# REF: i have three cats and a dog
# HYP: i have three kids and a dog
#
# REF: they don't need that seven day waiting period
# HYP: they don't need that seven day waiting period
#
# REF: of course it's real convenient
# HYP: of course it's real convenience
#
# REF: my husband and i both went
# HYP: my husband and i both went
#
# REF: you learn more about the characters and stuff
# HYP: you learn more about the actors and stuff
#
# REF: just a little shell to go under a suit
# HYP: this a little while to go on a suit
#
# REF: then we put our receipts in there
# HYP: then we put our trust in there
#
# REF: where is it going to be
# HYP: where is it going to be
#
# REF: fifty nine kilometers per gallon
# HYP: fifty nine kilometers per gallon
#
# REF: they'd seen it earlier
# HYP: they'd seen it all
#
# REF: it shouldn't be destroyed
# HYP: it shouldn't be decided
#
# REF: chemical services to come
# HYP: sample sizes to come
#
# REF: which i thought was a real interesting question
# HYP: which which i thought was a real any occasion
#
# REF: well that's about it really
# HYP: well that's about it really
#
# REF: if i don't have a reel with a button on it
# HYP: if i don't have a real with a ban on it
#
# REF: you get a lot of sunfish
# HYP: you get a lot of unrest
#
# REF: i enjoy going to the beach and to beach areas
# HYP: i enjoy going to the facts and to reach areas
#
# REF: i guess i'm partial to big tree country
# HYP: i guess i'm partial to big tree country
#
# REF: they are both remarried
# HYP: they are both remarried
#
# REF: the high school i went to
# HYP: the high school i went to
#
# REF: you have to think grandchildren
# HYP: you have to think grandchildren
#
# REF: you could do it
# HYP: you could do it
#
# REF: he was treated like all the rest of students
# HYP: i was treated like all the rest of students
#
# REF: i don't think so anymore
# HYP: i don't think so anymore
#
# REF: that's still not enough for a total
# HYP: that's just not enough for a total
#
# REF: one thing led to another
# HYP: one thing led to another
#
# REF: two different parts of the country
# HYP: you have one of the country
#
# REF: i really don't have any job benefits to speak of
# HYP: i will have a job and to pick off
#
# REF: it really helps those people
# HYP: it will be those people
#
# REF: put a cramp in your viewing
# HYP: but a cramp in your writing
#
# REF: it's a pretty good size church
# HYP: it's a pretty good size torch
#
# REF: camping for you in a motor home
# HYP: something for you in a motor home
#
# REF: if you've only got a token force there
# HYP: if you've only got a talking point there
#
# REF: this time of the year
# HYP: this time of the year
#
# REF: i'd just as soon a lot fewer people did
# HYP: it just has seen a lot more people did
#
# REF: they think it's kind of cool
# HYP: they think it's kind of cool
#
# REF: crime is too much
# HYP: time is too much
#
# REF: i don't know how my father did it
# HYP: i don't know how my brother did it
#
# REF: lived on a farm for sixty years
# HYP: leave on a farm for six years
#
# REF: i look at homemaking as a job also
# HYP: i look at something as a raw files
#
# REF: really kind of gone the rounds
# HYP: really kind of done the rounds
#
# REF: i never even knew that
# HYP: i never even knew that
#
# REF: clothing and gas
# HYP: sterling and gas
#
# REF: the commercial districts
# HYP: the commercial district
#
# REF: what's the difference there
# HYP: that's the difference there
#
# REF: i like that kind of stuff
# HYP: i like that kind of stuff
#
# REF: we might as well
# HYP: we might as well
#
# REF: savings and loans
# HYP: taking on loans
#
# REF: they plastered over drywall
# HYP: they plastered over as well
#
# REF: i'll slice white grape
# HYP: i'll list what keeps
#
# REF: the bomb development
# HYP: the from development
#
# REF: on the outskirts of houston
# HYP: on the outskirts of houston
#
# REF: i forget how she got it
# HYP: i forget how she got it
#
# REF: your tuition reimbursement
# HYP: your decision important
#
# REF: getting pledge sheets for the boy scouts
# HYP: cutting back seat for the bay state
#
# REF: if you have any doubts whatsoever
# HYP: if you have any rights whatsoever
#
# REF: mystery movies
# HYP: scary movie
#
# REF: i can't remember where
# HYP: i can't remember where
#
# WER: 0.19

# %% [markdown]
# #### Exercise 4 (optional)
#
# Sweep the LM decoder parameters
